# %%
# Import python packages
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process as fwprocess
import rpy2
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

# %%
# Can uncomment to install R packages as needed
#utils = importr('utils')
#utils.install_packages('nflreadr')
#utils.install_packages('ffscrapr')

# %%
# Import R packages
nflreadr = importr('nflreadr')
ffscrapr = importr('ffscrapr')

# %%
# Config for the calculation
mfl_id = 60206  #MFL id for league
seasons = [2024,2023,2022]  #Seasons to collect data for
max_week = 17  #Maximum week number to include in calculation
num_off = 7  #Number of offensive players to include in calculation for each game
num_def = 12  #Number of defensive  players to include in calculation for each game
save_label = 'Analytics_Dynasty_League_2025'  #Where to save results

# %%
# A mapping from PFR team names to MFL team names

###
team_dic = {
    'ARI' : 'ARI',
    'ATL' : 'ATL',
    'BAL' : 'BAL',
    'BUF' : 'BUF',
    'CAR' : 'CAR',
    'CHI' : 'CHI',
    'CIN' : 'CIN',
    'CLE' : 'CLE',
    'DAL' : 'DAL',
    'DEN' : 'DEN',
    'DET' : 'DET',
    'GB' : 'GBP',
    'HOU' : 'HOU',
    'IND' : 'IND',
    'JAX' : 'JAC',
    'KC' : 'KCC',
    'LA' : 'LAR',
    'LAC' : 'LAC',
    'LV' : 'LVR',
    'MIA' : 'MIA',
    'MIN' : 'MIN',
    'NE' : 'NEP',
    'NO' : 'NOS',
    'NYG' : 'NYG',
    'NYJ' : 'NYJ',
    'PHI' : 'PHI',
    'PIT' : 'PIT',
    'SEA' : 'SEA',
    'SF' : 'SFO',
    'TB' : 'TBB',
    'TEN' : 'TEN',
    'WAS' : 'WAS',
}

# %%
# Mappings for positions, both to consider which positions to drop from the analysis and to cleanup PFR positions a bit

###
snap_side_map = {
    'C' : 'DROP',
    'CB' : 'DEF',
    'DB' : 'DEF',
    'DE' : 'DEF',
    'DT' : 'DEF',
    'FB' : 'DROP',  #Change to OFF if want to include FBs
    'FS' : 'DEF',
    'G' : 'DROP',
    'K' : 'DROP',
    'LB' : 'DEF',
    'LS' : 'DROP',
    'NT' : 'DEF',
    'P' : 'DROP',
    'QB' : 'OFF',
    'RB' : 'OFF',
    'SS' : 'DEF',
    'T' : 'DROP',
    'TE' : 'OFF',
    'WR' : 'OFF',
}

snap_position_map = {
    'CB' : 'CB',
    'DB' : 'S',
    'DE' : 'DE',
    'DT' : 'DT',
    'FB' : 'RB',
    'FS' : 'S',
    'LB' : 'LB',
    'NT' : 'DT',
    'QB' : 'QB',
    'RB' : 'RB',
    'SS' : 'S',
    'TE' : 'TE',
    'WR' : 'WR',
}

###
pos_side_map = {
    'CB' : 'DEF',
    'Coach' : 'DROP',
    'DE' : 'DEF',
    'DT' : 'DEF',
    'Def' : 'DROP',
    'LB' : 'DEF',
    'Off' : 'DROP',
    'PK' : 'DROP',
    'PN' : 'DROP',
    'QB' : 'OFF',
    'RB' : 'OFF',
    'S' : 'DEF',
    'ST' : 'DROP',
    'TE' : 'OFF',
    'TMDB' : 'DROP',
    'TMDL' : 'DROP',
    'TMLB' : 'DROP',
    'TMPK' : 'DROP',
    'TMPN' : 'DROP',
    'TMQB' : 'DROP',
    'TMRB' : 'DROP',
    'TMTE' : 'DROP',
    'TMWR' : 'DROP',
    'WR' : 'OFF',
    'XX' : 'DROP'}

# %%
# Scrape snap counts from PFR and convert to pandas df
snap_df_r = nflreadr.load_snap_counts(ro.IntVector(seasons))

with (ro.default_converter + pandas2ri.converter).context():
  snap_df = ro.conversion.get_conversion().rpy2py(snap_df_r)

# Cleanup some of the data
snap_df['team'] = snap_df['team'].apply(lambda x: team_dic[x])
snap_df['side'] = snap_df['position'].apply(lambda x: snap_side_map[x])

snap_df = snap_df[ snap_df['side'] != 'DROP' ]

snap_df['position'] = snap_df['position'].apply(lambda x: snap_position_map[x])
snap_df['player_pfr'] = snap_df['player'].apply(lambda x: nflreadr.clean_player_names(x, convert_lastfirst=False)[0])
snap_df['join_string'] = snap_df['player_pfr'] + " " + snap_df['team'] + " " + snap_df['position']

snap_df
# Out:
# Note: nflreadr caches (i.e., stores a saved version) data by default.
# If you expect different output try one of the following:
# ℹ Restart your R Session or
# ℹ Run `nflreadr::.clear_cache()`.
# To disable this warning, run `options(nflreadr.verbose = FALSE)` or add it to your .Rprofile
# This message is displayed once every 8 hours.
#                game_id   pfr_game_id  season game_type  week          player  \
# 5      2024_01_ARI_BUF  202409080buf    2024       REG     1      Josh Allen
# 7      2024_01_ARI_BUF  202409080buf    2024       REG     1  Dalton Kincaid
# 8      2024_01_ARI_BUF  202409080buf    2024       REG     1    Keon Coleman
# 9      2024_01_ARI_BUF  202409080buf    2024       REG     1      James Cook
# 10     2024_01_ARI_BUF  202409080buf    2024       REG     1    Mack Hollins
# ...                ...           ...     ...       ...   ...             ...
# 79353   2022_22_KC_PHI  202302120phi    2022        SB    22   Darius Harris
# 79354   2022_22_KC_PHI  202302120phi    2022        SB    22       Deon Bush
# 79355   2022_22_KC_PHI  202302120phi    2022        SB    22   Jack Cochrane
# 79356   2022_22_KC_PHI  202302120phi    2022        SB    22  Nazeeh Johnson
# 79357   2022_22_KC_PHI  202302120phi    2022        SB    22     Marcus Kemp
#
#       pfr_player_id position team opponent  offense_snaps  offense_pct  \
# 5          AlleJo02       QB  BUF      ARI           62.0         1.00
# 7          KincDa00       TE  BUF      ARI           52.0         0.84
# 8          ColeKe02       WR  BUF      ARI           45.0         0.73
# 9          CookJa01       RB  BUF      ARI           38.0         0.61
# 10         HollMa00       WR  BUF      ARI           36.0         0.58
# ...             ...      ...  ...      ...            ...          ...
# 79353      HarrDa07       LB  KCC      PHI            0.0         0.00
# 79354      BushDe00        S  KCC      PHI            0.0         0.00
# 79355      CochJa00       LB  KCC      PHI            0.0         0.00
# 79356      JohnNa01        S  KCC      PHI            0.0         0.00
# 79357      KempMa00       WR  KCC      PHI            0.0         0.00
#
#        defense_snaps  defense_pct  st_snaps  st_pct side      player_pfr  \
# 5                0.0         0.00       0.0    0.00  OFF      Josh Allen
# 7                0.0         0.00       0.0    0.00  OFF  Dalton Kincaid
# 8                0.0         0.00       0.0    0.00  OFF    Keon Coleman
# 9                0.0         0.00       0.0    0.00  OFF      James Cook
# 10               0.0         0.00      10.0    0.37  OFF    Mack Hollins
# ...              ...          ...       ...     ...  ...             ...
# 79353            2.0         0.03      16.0    0.55  DEF   Darius Harris
# 79354            1.0         0.01      20.0    0.69  DEF       Deon Bush
# 79355            0.0         0.00      17.0    0.59  DEF   Jack Cochrane
# 79356            0.0         0.00      17.0    0.59  DEF  Nazeeh Johnson
# 79357            0.0         0.00      17.0    0.59  OFF     Marcus Kemp
#
#                  join_string
# 5          Josh Allen BUF QB
# 7      Dalton Kincaid BUF TE
# 8        Keon Coleman BUF WR
# 9          James Cook BUF RB
# 10       Mack Hollins BUF WR
# ...                      ...
# 79353   Darius Harris KCC LB
# 79354        Deon Bush KCC S
# 79355   Jack Cochrane KCC LB
# 79356   Nazeeh Johnson KCC S
# 79357     Marcus Kemp KCC WR
#
# [60669 rows x 19 columns]

# %%
# Dict to store data for each season
pos_df = {}

for s in seasons:
    # Scrape player positions from MFL and convert to pandas df
    mfl = ffscrapr.mfl_connect(season=s, league_id=mfl_id)
    
    pos_df_r = ffscrapr.mfl_players(mfl)
    
    with (ro.default_converter + pandas2ri.converter).context():
      pos_df[s] = ro.conversion.get_conversion().rpy2py(pos_df_r)

    # Cleanup some of the data
    pos_df[s]['season'] = s
    pos_df[s]['side'] = pos_df[s]['pos'].apply(lambda x: pos_side_map[x])

    pos_df[s] = pos_df[s][ pos_df[s]['side'] != 'DROP' ]
    
    pos_df[s]['player_mfl'] = pos_df[s]['player_name'].apply(lambda x: nflreadr.clean_player_names(x, convert_lastfirst=True)[0])
    pos_df[s]['join_string'] = pos_df[s]['player_mfl'] + " " + pos_df[s]['team'] + " " + pos_df[s]['pos']

# Merge seasons to single df
pos_df = pd.concat(pos_df, ignore_index=True)

# Sort by id and season for cleaner display
pos_df = pos_df.set_index(['player_id','season']).sort_index(level=[0,1],ascending=[True,True]).reset_index()

# Save a copy of positions
pos_df[['player_id','player_mfl','season','team','side','pos','join_string']].to_csv(f'{save_label}_Positions.csv', index=False)

pos_df
# Out:
#      player_id  season            player_name pos   age team         status  \
# 0         0800    2022  Weatherford, Sterling   S   NaN  IND              R
# 1         0802    2022           Krull, Lucas  TE   NaN  NOS              R
# 2         0803    2022          Vilain, Luiji  DE   NaN  MIN              R
# 3        10143    2022        Mclendon, Steve  DT  39.1   FA  NA_character_
# 4        10220    2022        Sendejo, Andrew   S  37.4   FA  NA_character_
# ...        ...     ...                    ...  ..   ...  ...            ...
# 6836      9940    2022              Woods, Al  DT  37.9  SEA  NA_character_
# 6837      9940    2023              Woods, Al  DT  37.9  NYJ  NA_character_
# 6838      9940    2024              Woods, Al  DT  37.9   FA  NA_character_
# 6839      9988    2022         Brown, Antonio  WR  36.6   FA  NA_character_
# 6840      9988    2023         Brown, Antonio  WR  36.6   FA  NA_character_
#
#          draft_team     draft_year    draft_round  ...                 nfl_id  \
# 0     NA_character_  NA_character_  NA_character_  ...          NA_character_
# 1     NA_character_  NA_character_  NA_character_  ...          NA_character_
# 2     NA_character_  NA_character_  NA_character_  ...          NA_character_
# 3                FA           2009  NA_character_  ...  stevemclendon/2507590
# 4                FA           2010  NA_character_  ...  andrewsendejo/2525323
# ...             ...            ...            ...  ...                    ...
# 6836            NOS           2010              4  ...         alwoods/496881
# 6837            NOS           2010              4  ...         alwoods/496881
# 6838            NOS           2010              4  ...         alwoods/496881
# 6839            PIT           2010              6  ...   antoniobrown/2508061
# 6840            PIT           2010              6  ...   antoniobrown/2508061
#
#      twitter_username         jersey           college         height  \
# 0       NA_character_  NA_character_     NA_character_  NA_character_
# 1       NA_character_  NA_character_     NA_character_  NA_character_
# 2       NA_character_  NA_character_     NA_character_  NA_character_
# 3       NA_character_             96              Troy             75
# 4            Asendejo             42              Rice             73
# ...               ...            ...               ...            ...
# 6836    NA_character_             96               LSU             76
# 6837    NA_character_             96               LSU             76
# 6838    NA_character_             96               LSU             76
# 6839   AntonioBrown84             81  Central Michigan             70
# 6840   AntonioBrown84             81  Central Michigan             70
#
#              weight birthdate side            player_mfl  \
# 0     NA_character_       NaN  DEF  Sterling Weatherford
# 1     NA_character_       NaN  OFF           Lucas Krull
# 2     NA_character_       NaN  DEF          Luiji Vilain
# 3               310    5846.0  DEF        Steve McLendon
# 4               210    6460.0  DEF        Andrew Sendejo
# ...             ...       ...  ...                   ...
# 6836            309    6292.0  DEF              Al Woods
# 6837            309    6292.0  DEF              Al Woods
# 6838            309    6292.0  DEF              Al Woods
# 6839            185    6765.0  OFF         Antonio Brown
# 6840            185    6765.0  OFF         Antonio Brown
#
#                      join_string
# 0     Sterling Weatherford IND S
# 1             Lucas Krull NOS TE
# 2            Luiji Vilain MIN DE
# 3           Steve McLendon FA DT
# 4            Andrew Sendejo FA S
# ...                          ...
# 6836             Al Woods SEA DT
# 6837             Al Woods NYJ DT
# 6838              Al Woods FA DT
# 6839         Antonio Brown FA WR
# 6840         Antonio Brown FA WR
#
# [6841 rows x 29 columns]

# %%
###
def GetClosestJoinString(other_df, this_js):
    # Return closest matching join string using fuzzy matching
    return fwprocess.extract(this_js, other_df['join_string'], scorer=fuzz.ratio)[0][0]

def GetClosestJoinScore(other_df, this_js):
    # Return score of closest match using fuzzy matching
    return fwprocess.extract(this_js, other_df['join_string'], scorer=fuzz.ratio)[0][1]

# %%
# Initialize merged df from snap data
df = snap_df[['game_id','season','week','pfr_player_id','player_pfr','team','position','side','join_string','offense_snaps','defense_snaps']].copy()

# Filter out weeks above max week
df = df[ df['week'] <= max_week ]

# Merge in positions using fuzzy string matching, considering each season and side of ball separately
df = df.set_index(['pfr_player_id','season','week']).sort_index(level=[0,1,2],ascending=[True,True,True])

for s in seasons:
    for side in ['OFF','DEF']:
        print(s,side)

        # Constrain data to this season and side of ball
        tmp_snap_df = snap_df[ (snap_df['season'] == s) & (snap_df['side'] == side) ]
        tmp_snap_df = tmp_snap_df.set_index(['pfr_player_id','season','week']).sort_index(level=[0,1,2],ascending=[True,True,True])
        tmp_snap_df = tmp_snap_df.groupby(['pfr_player_id','season']).tail(1).droplevel(2)

        tmp_pos_df = pos_df[ (pos_df['season'] == s) & (pos_df['side'] == side) ]

        # Fill the df with the closest matching join_string found by the fuzzy matching
        df.loc[ (df.index.get_level_values(1) == s) & (df['side'] == side), 'join_string'] = tmp_snap_df['join_string'].apply(lambda x: GetClosestJoinString(tmp_pos_df, x))

df = df.reset_index()

# With common join strings now in hand, we can merge in the pfl position and player data from MFL
df = df.set_index(['join_string','season']).sort_index(level=[0,1],ascending=[True,True])
df = df.join( pos_df.set_index(['join_string','season']).sort_index(level=[0,1],ascending=[True,True])[['pos','player_mfl']] )

df = df.reset_index()

# Rename the position columns
df = df.rename(columns={'position':'pfr_position'})
df = df.rename(columns={'pos':'position'})

# Find the per-game snap ranks for each player, assign qualifying players weight of 1, and break ties at the boundary with fractional weight
df = df.set_index(['game_id','team']).sort_index(level=[0,1],ascending=[True,True])

df['offense_rank'] = df.groupby(['game_id','team']).apply(lambda x: x['offense_snaps'].rank(method='first',ascending=False)).values  #Snap rank
df['offense_thresh'] = df.groupby(['game_id','team']).apply(lambda x: x['offense_snaps'][ x['offense_rank'] == num_off ].values[0])  #Snap boundary
df['offense_weight'] = ( (df['offense_rank'] <= num_off).values | (df['offense_snaps'] == df['offense_thresh']).values ).astype(float)  #Initial weights
thresh_inds = df['offense_snaps'] == df['offense_thresh']
df.loc[ thresh_inds, 'offense_weight' ] = df[thresh_inds].groupby(['game_id','team']).apply(lambda x: np.sum(x['offense_rank'] <= num_off) / len(x) )  #Normalize weights by breaking ties

df['defense_rank'] = df.groupby(['game_id','team']).apply(lambda x: x['defense_snaps'].rank(method='first',ascending=False)).values  #Snap rank
df['defense_thresh'] = df.groupby(['game_id','team']).apply(lambda x: x['defense_snaps'][ x['defense_rank'] == num_def ].values[0])  #Snap boundary
df['defense_weight'] = ( (df['defense_rank'] <= num_def).values | (df['defense_snaps'] == df['defense_thresh']).values ).astype(float)  #Initial weights
thresh_inds = df['defense_snaps'] == df['defense_thresh']
df.loc[ thresh_inds, 'defense_weight' ] = df[thresh_inds].groupby(['game_id','team']).apply(lambda x: np.sum(x['defense_rank'] <= num_def) / len(x) )  #Normalize weights by breaking ties

df = df.reset_index()

# Sort by season, week, game_id, and team for cleaner display
df = df.set_index(['season','week','game_id','team','offense_snaps','defense_snaps']).sort_index(level=[0,1,2,3,4,5],ascending=[True,True,True,True,False,False]).reset_index()

# Save a copy of the raw data
df.to_csv(f'{save_label}_Raw.csv', index=False)

df
# Out:
# 2024 OFF
# 2024 DEF
# 2023 OFF
# 2023 DEF
# 2022 OFF
# 2022 DEF
#        season  week          game_id team  offense_snaps  defense_snaps  \
# 0        2022     1  2022_01_BAL_NYJ  BAL           56.0            0.0
# 1        2022     1  2022_01_BAL_NYJ  BAL           47.0            0.0
# 2        2022     1  2022_01_BAL_NYJ  BAL           37.0            0.0
# 3        2022     1  2022_01_BAL_NYJ  BAL           33.0            0.0
# 4        2022     1  2022_01_BAL_NYJ  BAL           29.0            0.0
# ...       ...   ...              ...  ...            ...            ...
# 54604    2024    17  2024_17_TEN_JAX  TEN            0.0            1.0
# 54605    2024    17  2024_17_TEN_JAX  TEN            0.0            0.0
# 54606    2024    17  2024_17_TEN_JAX  TEN            0.0            0.0
# 54607    2024    17  2024_17_TEN_JAX  TEN            0.0            0.0
# 54608    2024    17  2024_17_TEN_JAX  TEN            0.0            0.0
#
#                    join_string pfr_player_id        player_pfr pfr_position  \
# 0         Lamar Jackson BAL QB      JackLa00     Lamar Jackson           QB
# 1          Mark Andrews BAL TE      AndrMa00      Mark Andrews           TE
# 2        Rashod Bateman BAL WR      BateRa00    Rashod Bateman           WR
# 3          Kenyan Drake BAL RB      DrakKe00      Kenyan Drake           RB
# 4        Devin Duvernay BAL WR      DuveDe00    Devin Duvernay           WR
# ...                        ...           ...               ...          ...
# 54604    James Williams TEN LB      WillJa15    James Williams           LB
# 54605       Cedric Gray TEN LB      GrayCe00       Cedric Gray           LB
# 54606     Justin Hardee TEN CB      HardJu01     Justin Hardee           CB
# 54607     Kendell Brooks TEN S      BrooKe02    Kendell Brooks            S
# 54608  Raekwon McMillan TEN LB      McMiRa02  Raekwon McMillan           LB
#
#       side position        player_mfl  offense_rank  offense_thresh  \
# 0      OFF       QB     Lamar Jackson           1.0            25.0
# 1      OFF       TE      Mark Andrews           2.0            25.0
# 2      OFF       WR    Rashod Bateman           3.0            25.0
# 3      OFF       RB      Kenyan Drake           4.0            25.0
# 4      OFF       WR    Devin Duvernay           5.0            25.0
# ...    ...      ...               ...           ...             ...
# 54604  DEF       LB    James Williams          22.0            25.0
# 54605  DEF       LB       Cedric Gray          15.0            25.0
# 54606  DEF       CB     Justin Hardee          27.0            25.0
# 54607  DEF        S    Kendell Brooks          28.0            25.0
# 54608  DEF       LB  Raekwon McMillan          32.0            25.0
#
#        offense_weight  defense_rank  defense_thresh  defense_weight
# 0                 1.0          31.0            41.0             0.0
# 1                 1.0          32.0            41.0             0.0
# 2                 1.0          34.0            41.0             0.0
# 3                 1.0          29.0            41.0             0.0
# 4                 1.0          22.0            41.0             0.0
# ...               ...           ...             ...             ...
# 54604             0.0          19.0            25.0             0.0
# 54605             0.0          22.0            25.0             0.0
# 54606             0.0          27.0            25.0             0.0
# 54607             0.0          28.0            25.0             0.0
# 54608             0.0          33.0            25.0             0.0
#
# [54609 rows x 19 columns]

# %%
# Calculate the mean value for each season-team-position by summing over weights and dividing by number of games
df = df.set_index(['season','team','position']).sort_index(level=[0,1,2],ascending=[True,True,True])

result_off = df['offense_weight'].groupby(['season','team','position']).sum() / df.groupby(['season','team']).apply(lambda x: len(set(x['week'])))
result_off = result_off[ result_off >= 0.1 ]

result_def = df['defense_weight'].groupby(['season','team','position']).sum() / df.groupby(['season','team']).apply(lambda x: len(set(x['week'])))
result_def = result_def[ result_def >= 0.1 ]

df = df.reset_index()

# Pivot results out to columns to put into a nice tabular form
result_off = result_off.unstack(level=-1)
result_def = result_def.unstack(level=-1)

# Calculate values for DL and DB positions
result_def['DL'] = result_def['DT'] + result_def['DE']
result_def['DB'] = result_def['CB'] + result_def['S']

# Cleanup the table, listing the sorted values and season-teams for each position
result_dic = {}

for c in ['QB','RB','WR','TE']:
    tmp_df = result_off[c].reset_index()
    
    tmp_df[f'{c} Team'] = tmp_df['season'].map(str) + " " + tmp_df['team']
    tmp_df = tmp_df[[c, f'{c} Team']].rename(columns={c:f'{c} Value'})
    tmp_df = tmp_df.sort_values(f'{c} Value', ascending=False).reset_index(drop=True)

    result_dic[c] = tmp_df

for c in ['DT','DE','LB','CB','S','DL','DB']:
    tmp_df = result_def[c].reset_index()
    
    tmp_df[f'{c} Team'] = tmp_df['season'].map(str) + " " + tmp_df['team']
    tmp_df = tmp_df[[c, f'{c} Team']].rename(columns={c:f'{c} Value'})
    tmp_df = tmp_df.sort_values(f'{c} Value', ascending=False).reset_index(drop=True)

    result_dic[c] = tmp_df

# Save the table to a csv
result = pd.concat(result_dic, axis=1, ignore_index=False)
result.columns = result.columns.droplevel(0)

result.to_csv(f'{save_label}_Lineups.csv', index=False)

# %%
# Full results
result
# Out:
#     QB Value   QB Team  RB Value   RB Team  WR Value   WR Team  TE Value  \
# 0    1.12500  2023 NOS   1.71875  2024 TBB  3.625000  2023 TBB   2.53125
# 1    1.09375  2024 NYG   1.68750  2024 CHI  3.593750  2023 DAL   2.25000
# 2    1.06250  2022 ARI   1.68750  2022 CLE  3.562500  2023 BAL   2.21875
# 3    1.06250  2023 WAS   1.62500  2023 PHI  3.531250  2022 CHI   2.18750
# 4    1.06250  2023 ATL   1.62500  2022 DAL  3.500000  2024 GBP   2.09375
# ..       ...       ...       ...       ...       ...       ...       ...
# 91   1.00000  2022 IND   1.00000  2023 JAC  2.625000  2024 PIT   1.18750
# 92   1.00000  2023 PHI   0.96875  2024 DEN  2.520833  2022 ATL   1.15625
# 93   1.00000  2023 PIT   0.93750  2024 NOS  2.406250  2024 MIA   1.12500
# 94   1.00000  2022 NYG   0.93750  2024 BUF  2.406250  2022 BAL   1.06250
# 95   1.00000  2024 WAS   0.81250  2024 KCC  2.156250  2023 ATL   1.06250
#
#      TE Team  DT Value   DT Team  ...  LB Value   LB Team  CB Value   CB Team  \
# 0   2023 ATL   3.25000  2024 SEA  ...   2.93750  2022 LAC  3.625000  2022 PHI
# 1   2024 NOS   3.18750  2023 ATL  ...   2.87500  2022 DAL  3.531250  2022 IND
# 2   2024 ARI   3.15625  2023 CAR  ...   2.81250  2022 ARI  3.500000  2022 CAR
# 3   2024 MIA   3.12500  2023 LAR  ...   2.78125  2024 DET  3.437500  2023 TBB
# 4   2022 NOS   3.12500  2022 ARI  ...   2.75000  2023 BAL  3.433333  2022 BUF
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 91  2022 CHI   1.71875  2023 CLE  ...   1.71875  2023 CAR  2.312500  2022 SFO
# 92  2023 MIA   1.68750  2023 DET  ...   1.68750  2023 LAR  2.218750  2023 MIN
# 93  2022 LAR   1.65625  2023 IND  ...   1.59375  2023 MIN  2.187500  2023 DET
# 94  2023 BAL   1.43750  2023 DAL  ...   1.31250  2024 MIN  2.187500  2022 BAL
# 95  2024 TBB   1.31250  2022 DAL  ...   1.31250  2023 DAL  2.062500  2024 HOU
#
#     S Value    S Team  DL Value   DL Team  DB Value   DB Team
# 0   3.62500  2023 DAL   5.50000  2022 JAC  6.625000  2023 DAL
# 1   3.09375  2024 HOU   5.40625  2023 CAR  5.875000  2022 DAL
# 2   3.06250  2024 KCC   5.37500  2022 MIA  5.687500  2022 NEP
# 3   3.00000  2022 BAL   5.31250  2022 ATL  5.500000  2024 WAS
# 4   3.00000  2024 MIN   5.25000  2024 MIN  5.437500  2022 CAR
# ..      ...       ...       ...       ...       ...       ...
# 91  1.62500  2022 IND   4.25000  2022 NEP  4.625000  2024 DET
# 92  1.62500  2024 TBB   4.21875  2023 BAL  4.562500  2022 ATL
# 93  1.56250  2023 TBB   4.18750  2022 LAC  4.541667  2022 MIA
# 94  1.37500  2022 PHI   4.06250  2023 DAL  4.437500  2022 JAC
# 95  1.25000  2024 DET   3.25000  2022 DAL  4.250000  2022 ARI
#
# [96 rows x 22 columns]

# %%
# Team 2
result.iloc[1]
# Out:
# QB Value     1.09375
# QB Team     2024 NYG
# RB Value      1.6875
# RB Team     2024 CHI
# WR Value     3.59375
# WR Team     2023 DAL
# TE Value        2.25
# TE Team     2024 NOS
# DT Value      3.1875
# DT Team     2023 ATL
# DE Value       3.125
# DE Team     2024 MIN
# LB Value       2.875
# LB Team     2022 DAL
# CB Value     3.53125
# CB Team     2022 IND
# S Value      3.09375
# S Team      2024 HOU
# DL Value     5.40625
# DL Team     2023 CAR
# DB Value       5.875
# DB Team     2022 DAL
# Name: 1, dtype: object

# %%
# Team 48 (half of median)
result.iloc[47]
# Out:
# QB Value         1.0
# QB Team     2024 SFO
# RB Value     1.21875
# RB Team     2023 ARI
# WR Value      3.0625
# WR Team     2023 PIT
# TE Value      1.6875
# TE Team     2022 CLE
# DT Value      2.4375
# DT Team     2022 WAS
# DE Value      2.3125
# DE Team     2022 BAL
# LB Value      2.0625
# LB Team     2022 NEP
# CB Value     2.90625
# CB Team     2022 KCC
# S Value        2.125
# S Team      2022 MIA
# DL Value       4.875
# DL Team     2022 CHI
# DB Value      5.0625
# DB Team     2024 DEN
# Name: 47, dtype: object

# %%
# Team 49 (half of median)
result.iloc[48]
# Out:
# QB Value         1.0
# QB Team     2022 BUF
# RB Value     1.21875
# RB Team     2022 KCC
# WR Value      3.0625
# WR Team     2023 NYJ
# TE Value    1.666667
# TE Team     2022 CIN
# DT Value    2.427083
# DT Team     2024 NEP
# DE Value      2.3125
# DE Team     2022 NYJ
# LB Value      2.0625
# LB Team     2024 HOU
# CB Value       2.875
# CB Team     2024 SFO
# S Value        2.125
# S Team      2024 CIN
# DL Value     4.84375
# DL Team     2023 IND
# DB Value      5.0625
# DB Team     2023 LAC
# Name: 48, dtype: object

# %%
# Team 95
result.iloc[94]
# Out:
# QB Value         1.0
# QB Team     2022 NYG
# RB Value      0.9375
# RB Team     2024 BUF
# WR Value     2.40625
# WR Team     2022 BAL
# TE Value      1.0625
# TE Team     2023 BAL
# DT Value      1.4375
# DT Team     2023 DAL
# DE Value     1.59375
# DE Team     2022 DET
# LB Value      1.3125
# LB Team     2024 MIN
# CB Value      2.1875
# CB Team     2022 BAL
# S Value        1.375
# S Team      2022 PHI
# DL Value      4.0625
# DL Team     2023 DAL
# DB Value      4.4375
# DB Team     2022 JAC
# Name: 94, dtype: object

# %%
# Examine instances where player names don't match
print(len(df[ (df['player_pfr'] != df['player_mfl']) & (df['offense_weight'] + df['defense_weight'] > 0) ]))
# Out:
# 134

# %%
df[ (df['player_pfr'] != df['player_mfl']) & (df['offense_weight'] + df['defense_weight'] > 0) ].head(60)
# Out:
#        season team position  week          game_id  offense_snaps  \
# 598      2022  ATL       CB     5   2022_05_ATL_TB            0.0
# 2363     2022  CAR       DT     1  2022_01_CLE_CAR            0.0
# 2367     2022  CAR       DT     2  2022_02_CAR_NYG            0.0
# 2372     2022  CAR       DT     3   2022_03_NO_CAR            0.0
# 2377     2022  CAR       DT     4  2022_04_ARI_CAR            0.0
# 2382     2022  CAR       DT     5   2022_05_SF_CAR            0.0
# 2388     2022  CAR       DT     6   2022_06_CAR_LA            0.0
# 2398     2022  CAR       DT     8  2022_08_CAR_ATL            0.0
# 2401     2022  CAR       DT     9  2022_09_CAR_CIN            0.0
# 2407     2022  CAR       DT    10  2022_10_ATL_CAR            0.0
# 2420     2022  CAR       DT    14  2022_14_CAR_SEA            0.0
# 2425     2022  CAR       DT    15  2022_15_PIT_CAR            0.0
# 2430     2022  CAR       DT    16  2022_16_DET_CAR            0.0
# 2435     2022  CAR       DT    17   2022_17_CAR_TB            0.0
# 9650     2022  LAR       CB    14    2022_14_LV_LA            0.0
# 9655     2022  LAR       CB    15    2022_15_LA_GB            0.0
# 9661     2022  LAR       CB    16   2022_16_DEN_LA            0.0
# 9668     2022  LAR       CB    17   2022_17_LA_LAC            0.0
# 12395    2022  NEP       WR    16   2022_16_CIN_NE           22.0
# 17774    2022  WAS       LB     9  2022_09_MIN_WAS            0.0
# 17778    2022  WAS       LB    10  2022_10_WAS_PHI            0.0
# 17783    2022  WAS       LB    11  2022_11_WAS_HOU            0.0
# 17788    2022  WAS       LB    12  2022_12_ATL_WAS            0.0
# 17793    2022  WAS       LB    13  2022_13_WAS_NYG            0.0
# 17798    2022  WAS       LB    15  2022_15_NYG_WAS            0.0
# 18671    2023  ATL       CB     1  2023_01_CAR_ATL            0.0
# 18675    2023  ATL       CB     2   2023_02_GB_ATL            0.0
# 18679    2023  ATL       CB     3  2023_03_ATL_DET            0.0
# 18685    2023  ATL       CB     4  2023_04_ATL_JAX            0.0
# 18690    2023  ATL       CB     5  2023_05_HOU_ATL            0.0
# 18696    2023  ATL       CB     6  2023_06_WAS_ATL            0.0
# 18701    2023  ATL       CB     7   2023_07_ATL_TB            0.0
# 18706    2023  ATL       CB     8  2023_08_ATL_TEN            0.0
# 18711    2023  ATL       CB     9  2023_09_MIN_ATL            0.0
# 18722    2023  ATL       CB    12   2023_12_NO_ATL            0.0
# 18727    2023  ATL       CB    13  2023_13_ATL_NYJ            0.0
# 18732    2023  ATL       CB    14   2023_14_TB_ATL            0.0
# 18916    2023  ATL       LB     2   2023_02_GB_ATL            0.0
# 18924    2023  ATL       LB     4  2023_04_ATL_JAX            0.0
# 18928    2023  ATL       LB     5  2023_05_HOU_ATL            0.0
# 18931    2023  ATL       LB     6  2023_06_WAS_ATL            0.0
# 18934    2023  ATL       LB     7   2023_07_ATL_TB            0.0
# 18937    2023  ATL       LB     8  2023_08_ATL_TEN            0.0
# 18940    2023  ATL       LB     9  2023_09_MIN_ATL            0.0
# 18942    2023  ATL       LB    10  2023_10_ATL_ARI            0.0
# 18946    2023  ATL       LB    12   2023_12_NO_ATL            0.0
# 18949    2023  ATL       LB    13  2023_13_ATL_NYJ            0.0
# 18956    2023  ATL       LB    15  2023_15_ATL_CAR            0.0
# 18959    2023  ATL       LB    16  2023_16_IND_ATL            0.0
# 18962    2023  ATL       LB    17  2023_17_ATL_CHI            0.0
# 20392    2023  CAR       CB     9  2023_09_IND_CAR            0.0
# 20396    2023  CAR       CB    10  2023_10_CAR_CHI            0.0
# 20402    2023  CAR       CB    11  2023_11_DAL_CAR            0.0
# 25419    2023  HOU       WR     1  2023_01_HOU_BAL           37.0
# 27809    2023  LAR       CB     1   2023_01_LA_SEA            0.0
# 27813    2023  LAR       CB     2    2023_02_SF_LA            0.0
# 27818    2023  LAR       CB     3   2023_03_LA_CIN            0.0
# 27823    2023  LAR       CB     4   2023_04_LA_IND            0.0
# 27828    2023  LAR       CB     5   2023_05_PHI_LA            0.0
# 27833    2023  LAR       CB     6   2023_06_ARI_LA            0.0
#
#        defense_snaps                 join_string pfr_player_id  \
# 598             53.0           Dee Alford ATL CB      AlfoDe00
# 2363            48.0       Matt Ioannidis CAR DT      IoanMa01
# 2367            54.0       Matt Ioannidis CAR DT      IoanMa01
# 2372            51.0       Matt Ioannidis CAR DT      IoanMa01
# 2377            60.0       Matt Ioannidis CAR DT      IoanMa01
# 2382            49.0       Matt Ioannidis CAR DT      IoanMa01
# 2388            53.0       Matt Ioannidis CAR DT      IoanMa01
# 2398            55.0       Matt Ioannidis CAR DT      IoanMa01
# 2401            55.0       Matt Ioannidis CAR DT      IoanMa01
# 2407            49.0       Matt Ioannidis CAR DT      IoanMa01
# 2420            23.0       Matt Ioannidis CAR DT      IoanMa01
# 2425            50.0       Matt Ioannidis CAR DT      IoanMa01
# 2430            40.0       Matt Ioannidis CAR DT      IoanMa01
# 2435            54.0       Matt Ioannidis CAR DT      IoanMa01
# 9650            37.0       Decobie Durant LAR CB      DuraDe01
# 9655            46.0       Decobie Durant LAR CB      DuraDe01
# 9661            51.0       Decobie Durant LAR CB      DuraDe01
# 9668            48.0       Decobie Durant LAR CB      DuraDe01
# 12395            0.0  Montrell Washington DEN WR      WashSc00
# 17774           43.0           Jon Bostic WAS LB      BostJo00
# 17778           43.0           Jon Bostic WAS LB      BostJo00
# 17783           42.0           Jon Bostic WAS LB      BostJo00
# 17788           27.0           Jon Bostic WAS LB      BostJo00
# 17793           39.0           Jon Bostic WAS LB      BostJo00
# 17798           45.0           Jon Bostic WAS LB      BostJo00
# 18671           72.0           Dee Alford ATL CB      AlfoDe00
# 18675           24.0           Dee Alford ATL CB      AlfoDe00
# 18679           64.0           Dee Alford ATL CB      AlfoDe00
# 18685           40.0           Dee Alford ATL CB      AlfoDe00
# 18690           36.0           Dee Alford ATL CB      AlfoDe00
# 18696           46.0           Dee Alford ATL CB      AlfoDe00
# 18701           55.0           Dee Alford ATL CB      AlfoDe00
# 18706           39.0           Dee Alford ATL CB      AlfoDe00
# 18711           39.0           Dee Alford ATL CB      AlfoDe00
# 18722           46.0           Dee Alford ATL CB      AlfoDe00
# 18727           48.0           Dee Alford ATL CB      AlfoDe00
# 18732           51.0           Dee Alford ATL CB      AlfoDe00
# 18916           49.0         Nate Landman ATL LB      LandNa01
# 18924           54.0         Nate Landman ATL LB      LandNa01
# 18928           58.0         Nate Landman ATL LB      LandNa01
# 18931           39.0         Nate Landman ATL LB      LandNa01
# 18934           56.0         Nate Landman ATL LB      LandNa01
# 18937           56.0         Nate Landman ATL LB      LandNa01
# 18940           74.0         Nate Landman ATL LB      LandNa01
# 18942           65.0         Nate Landman ATL LB      LandNa01
# 18946           53.0         Nate Landman ATL LB      LandNa01
# 18949           40.0         Nate Landman ATL LB      LandNa01
# 18956           59.0         Nate Landman ATL LB      LandNa01
# 18959           71.0         Nate Landman ATL LB      LandNa01
# 18962           60.0         Nate Landman ATL LB      LandNa01
# 20392           42.0      DiCaprio Bootle CAR CB      BootDi00
# 20396           72.0      DiCaprio Bootle CAR CB      BootDi00
# 20402           69.0      DiCaprio Bootle CAR CB      BootDi00
# 25419            0.0            Tank Dell HOU WR      DellNa00
# 27809           40.0       Decobie Durant LAR CB      DuraDe01
# 27813           33.0       Decobie Durant LAR CB      DuraDe01
# 27818           61.0       Decobie Durant LAR CB      DuraDe01
# 27823           45.0       Decobie Durant LAR CB      DuraDe01
# 27828           53.0       Decobie Durant LAR CB      DuraDe01
# 27833           66.0       Decobie Durant LAR CB      DuraDe01
#
#               player_pfr pfr_position side           player_mfl  offense_rank  \
# 598      DeAundre Alford            S  DEF           Dee Alford          21.0
# 2363   Matthew Ioannidis           DT  DEF       Matt Ioannidis          26.0
# 2367   Matthew Ioannidis           DT  DEF       Matt Ioannidis          27.0
# 2372   Matthew Ioannidis           DT  DEF       Matt Ioannidis          29.0
# 2377   Matthew Ioannidis           DT  DEF       Matt Ioannidis          30.0
# 2382   Matthew Ioannidis           DT  DEF       Matt Ioannidis          29.0
# 2388   Matthew Ioannidis           DT  DEF       Matt Ioannidis          27.0
# 2398   Matthew Ioannidis           DT  DEF       Matt Ioannidis          29.0
# 2401   Matthew Ioannidis           DT  DEF       Matt Ioannidis          29.0
# 2407   Matthew Ioannidis           DT  DEF       Matt Ioannidis          29.0
# 2420   Matthew Ioannidis           DT  DEF       Matt Ioannidis          30.0
# 2425   Matthew Ioannidis           DT  DEF       Matt Ioannidis          28.0
# 2430   Matthew Ioannidis           DT  DEF       Matt Ioannidis          28.0
# 2435   Matthew Ioannidis           DT  DEF       Matt Ioannidis          29.0
# 9650        Cobie Durant           CB  DEF       Decobie Durant          17.0
# 9655        Cobie Durant           CB  DEF       Decobie Durant          17.0
# 9661        Cobie Durant           CB  DEF       Decobie Durant          20.0
# 9668        Cobie Durant           CB  DEF       Decobie Durant          18.0
# 12395  Scotty Washington           TE  OFF  Montrell Washington           7.0
# 17774    Jonathan Bostic           LB  DEF           Jon Bostic          27.0
# 17778    Jonathan Bostic           LB  DEF           Jon Bostic          28.0
# 17783    Jonathan Bostic           LB  DEF           Jon Bostic          27.0
# 17788    Jonathan Bostic           LB  DEF           Jon Bostic          27.0
# 17793    Jonathan Bostic           LB  DEF           Jon Bostic          26.0
# 17798    Jonathan Bostic           LB  DEF           Jon Bostic          26.0
# 18671    DeAundre Alford           CB  DEF           Dee Alford          22.0
# 18675    DeAundre Alford           CB  DEF           Dee Alford          23.0
# 18679    DeAundre Alford           CB  DEF           Dee Alford          18.0
# 18685    DeAundre Alford           CB  DEF           Dee Alford          21.0
# 18690    DeAundre Alford           CB  DEF           Dee Alford          22.0
# 18696    DeAundre Alford           CB  DEF           Dee Alford          21.0
# 18701    DeAundre Alford           CB  DEF           Dee Alford          21.0
# 18706    DeAundre Alford           CB  DEF           Dee Alford          22.0
# 18711    DeAundre Alford           CB  DEF           Dee Alford          22.0
# 18722    DeAundre Alford           CB  DEF           Dee Alford          22.0
# 18727    DeAundre Alford           CB  DEF           Dee Alford          23.0
# 18732    DeAundre Alford           CB  DEF           Dee Alford          22.0
# 18916     Nathan Landman           LB  DEF         Nate Landman          30.0
# 18924     Nathan Landman           LB  DEF         Nate Landman          29.0
# 18928     Nathan Landman           LB  DEF         Nate Landman          31.0
# 18931     Nathan Landman           LB  DEF         Nate Landman          31.0
# 18934     Nathan Landman           LB  DEF         Nate Landman          30.0
# 18937     Nathan Landman           LB  DEF         Nate Landman          32.0
# 18940     Nathan Landman           LB  DEF         Nate Landman          31.0
# 18942     Nathan Landman           LB  DEF         Nate Landman          31.0
# 18946     Nathan Landman           LB  DEF         Nate Landman          30.0
# 18949     Nathan Landman           LB  DEF         Nate Landman          31.0
# 18956     Nathan Landman           LB  DEF         Nate Landman          30.0
# 18959     Nathan Landman           LB  DEF         Nate Landman          32.0
# 18962     Nathan Landman           LB  DEF         Nate Landman          32.0
# 20392    Dicaprio Bootle           CB  DEF      DiCaprio Bootle          22.0
# 20396    Dicaprio Bootle           CB  DEF      DiCaprio Bootle          20.0
# 20402    Dicaprio Bootle           CB  DEF      DiCaprio Bootle          23.0
# 25419     Nathaniel Dell           WR  OFF            Tank Dell           6.0
# 27809       Cobie Durant           CB  DEF       Decobie Durant          17.0
# 27813       Cobie Durant           CB  DEF       Decobie Durant          17.0
# 27818       Cobie Durant           CB  DEF       Decobie Durant          16.0
# 27823       Cobie Durant           CB  DEF       Decobie Durant          18.0
# 27828       Cobie Durant           CB  DEF       Decobie Durant          18.0
# 27833       Cobie Durant           CB  DEF       Decobie Durant          18.0
#
#        offense_thresh  offense_weight  defense_rank  defense_thresh  \
# 598              21.0             0.0           8.0            38.0
# 2363             18.0             0.0          10.0            34.0
# 2367             18.0             0.0           8.0            38.0
# 2372             24.0             0.0           7.0            37.0
# 2377             22.0             0.0           7.0            32.0
# 2382             27.0             0.0           7.0            27.0
# 2388             23.0             0.0           5.0            30.0
# 2398             38.0             0.0           7.0            20.0
# 2401             18.0             0.0           7.0            26.0
# 2407             26.0             0.0           9.0            25.0
# 2420             24.0             0.0          12.0            23.0
# 2425             21.0             0.0          10.0            28.0
# 2430             30.0             0.0          11.0            29.0
# 2435             31.0             0.0          10.0            25.0
# 9650             19.0             0.0          11.0            36.0
# 9655             14.0             0.0          10.0            34.0
# 9661             38.0             0.0           6.0            34.0
# 9668             19.0             0.0           8.0            31.0
# 12395            22.0             1.0          31.0            41.0
# 17774            28.0             0.0          12.0            43.0
# 17778            40.0             0.0           8.0            22.0
# 17783            35.0             0.0           9.0            27.0
# 17788            30.0             0.0          12.0            27.0
# 17793            42.0             0.0           8.0            35.0
# 17798            36.0             0.0          10.0            25.0
# 18671            26.0             0.0           6.0            34.0
# 18675            38.0             0.0          12.0            24.0
# 18679            20.0             0.0           5.0            19.0
# 18685            19.0             0.0          10.0            28.0
# 18690            35.0             0.0          10.0            28.0
# 18696            29.0             0.0           6.0            15.0
# 18701            26.0             0.0           7.0            32.0
# 18706            31.0             0.0          11.0            33.0
# 18711            29.0             0.0          12.0            39.0
# 18722            23.0             0.0          10.0            37.0
# 18727            21.0             0.0           8.0            36.0
# 18732            23.0             0.0           7.0            34.0
# 18916            38.0             0.0           5.0            24.0
# 18924            19.0             0.0           5.0            28.0
# 18928            35.0             0.0           4.0            28.0
# 18931            29.0             0.0           9.0            15.0
# 18934            26.0             0.0           6.0            32.0
# 18937            31.0             0.0           6.0            33.0
# 18940            29.0             0.0           6.0            39.0
# 18942            28.0             0.0           4.0            27.0
# 18946            23.0             0.0           6.0            37.0
# 18949            21.0             0.0          11.0            36.0
# 18956            20.0             0.0           6.0            30.0
# 18959            24.0             0.0           4.0            27.0
# 18962            17.0             0.0           5.0            33.0
# 20392            31.0             0.0           8.0            27.0
# 20396            27.0             0.0           1.0            33.0
# 20402            27.0             0.0           5.0            32.0
# 25419            35.0             1.0          34.0            29.0
# 27809            28.0             0.0           9.0            20.0
# 27813            20.0             0.0          10.0            29.0
# 27818            12.0             0.0           9.0            33.0
# 27823            23.0             0.0           9.0            33.0
# 27828             9.0             0.0          10.0            36.0
# 27833             6.0             0.0           5.0            34.0
#
#        defense_weight
# 598               1.0
# 2363              1.0
# 2367              1.0
# 2372              1.0
# 2377              1.0
# 2382              1.0
# 2388              1.0
# 2398              1.0
# 2401              1.0
# 2407              1.0
# 2420              1.0
# 2425              1.0
# 2430              1.0
# 2435              1.0
# 9650              1.0
# 9655              1.0
# 9661              1.0
# 9668              1.0
# 12395             0.0
# 17774             1.0
# 17778             1.0
# 17783             1.0
# 17788             1.0
# 17793             1.0
# 17798             1.0
# 18671             1.0
# 18675             1.0
# 18679             1.0
# 18685             1.0
# 18690             1.0
# 18696             1.0
# 18701             1.0
# 18706             1.0
# 18711             1.0
# 18722             1.0
# 18727             1.0
# 18732             1.0
# 18916             1.0
# 18924             1.0
# 18928             1.0
# 18931             1.0
# 18934             1.0
# 18937             1.0
# 18940             1.0
# 18942             1.0
# 18946             1.0
# 18949             1.0
# 18956             1.0
# 18959             1.0
# 18962             1.0
# 20392             1.0
# 20396             1.0
# 20402             1.0
# 25419             0.0
# 27809             1.0
# 27813             1.0
# 27818             1.0
# 27823             1.0
# 27828             1.0
# 27833             1.0

# %%
df[ (df['player_pfr'] != df['player_mfl']) & (df['offense_weight'] + df['defense_weight'] > 0) ].head(120).tail(60)
# Out:
#        season team position  week          game_id  offense_snaps  \
# 27837    2023  LAR       CB     7   2023_07_PIT_LA            0.0
# 27857    2023  LAR       CB    12   2023_12_LA_ARI            0.0
# 27867    2023  LAR       CB    14   2023_14_LA_BAL            0.0
# 27875    2023  LAR       CB    16    2023_16_NO_LA            0.0
# 27879    2023  LAR       CB    17   2023_17_LA_NYG            0.0
# 33505    2023  SEA       CB     4  2023_04_SEA_NYG            0.0
# 33510    2023  SEA       CB     6  2023_06_SEA_CIN            0.0
# 33515    2023  SEA       CB     7  2023_07_ARI_SEA            0.0
# 33520    2023  SEA       CB     8  2023_08_CLE_SEA            0.0
# 33525    2023  SEA       CB     9  2023_09_SEA_BAL            0.0
# 33530    2023  SEA       CB    10  2023_10_WAS_SEA            0.0
# 33535    2023  SEA       CB    11   2023_11_SEA_LA            0.0
# 33541    2023  SEA       CB    12   2023_12_SF_SEA            0.0
# 33545    2023  SEA       CB    13  2023_13_SEA_DAL            0.0
# 33551    2023  SEA       CB    14   2023_14_SEA_SF            0.0
# 33561    2023  SEA       CB    16  2023_16_SEA_TEN            0.0
# 33568    2023  SEA       CB    17  2023_17_PIT_SEA            0.0
# 36190    2023  WAS        S    15   2023_15_WAS_LA            0.0
# 36196    2023  WAS        S    16  2023_16_WAS_NYJ            0.0
# 36199    2023  WAS        S    17   2023_17_SF_WAS            0.0
# 36922    2024  ATL       CB     1  2024_01_PIT_ATL            0.0
# 36926    2024  ATL       CB     2  2024_02_ATL_PHI            0.0
# 36933    2024  ATL       CB     3   2024_03_KC_ATL            0.0
# 36939    2024  ATL       CB     4   2024_04_NO_ATL            0.0
# 36950    2024  ATL       CB     6  2024_06_ATL_CAR            0.0
# 36956    2024  ATL       CB     7  2024_07_SEA_ATL            0.0
# 36962    2024  ATL       CB     8   2024_08_ATL_TB            0.0
# 36970    2024  ATL       CB     9  2024_09_DAL_ATL            0.0
# 36988    2024  ATL       CB    13  2024_13_LAC_ATL            0.0
# 36994    2024  ATL       CB    14  2024_14_ATL_MIN            0.0
# 37000    2024  ATL       CB    15   2024_15_ATL_LV            0.0
# 37006    2024  ATL       CB    16  2024_16_NYG_ATL            0.0
# 37013    2024  ATL       CB    17  2024_17_ATL_WAS            0.0
# 37193    2024  ATL       LB     1  2024_01_PIT_ATL            0.0
# 37209    2024  ATL       LB     6  2024_06_ATL_CAR            0.0
# 37212    2024  ATL       LB     7  2024_07_SEA_ATL            0.0
# 37215    2024  ATL       LB     8   2024_08_ATL_TB            0.0
# 37218    2024  ATL       LB     9  2024_09_DAL_ATL            0.0
# 37221    2024  ATL       LB    10   2024_10_ATL_NO            0.0
# 37224    2024  ATL       LB    11  2024_11_ATL_DEN            0.0
# 37239    2024  ATL       LB    16  2024_16_NYG_ATL            0.0
# 37242    2024  ATL       LB    17  2024_17_ATL_WAS            0.0
# 44945    2024  KCC       CB     8    2024_08_KC_LV            0.0
# 44985    2024  KCC       CB    16   2024_16_HOU_KC            0.0
# 44989    2024  KCC       CB    17   2024_17_KC_PIT            0.0
# 46049    2024  LAR       CB     1   2024_01_LA_DET            0.0
# 46054    2024  LAR       CB     2   2024_02_LA_ARI            0.0
# 46061    2024  LAR       CB     3    2024_03_SF_LA            0.0
# 46066    2024  LAR       CB     4   2024_04_LA_CHI            0.0
# 46075    2024  LAR       CB     5    2024_05_GB_LA            0.0
# 46084    2024  LAR       CB     7    2024_07_LV_LA            0.0
# 46090    2024  LAR       CB     8   2024_08_MIN_LA            0.0
# 46095    2024  LAR       CB     9   2024_09_LA_SEA            0.0
# 46102    2024  LAR       CB    10   2024_10_MIA_LA            0.0
# 46109    2024  LAR       CB    11    2024_11_LA_NE            0.0
# 46113    2024  LAR       CB    12   2024_12_PHI_LA            0.0
# 46118    2024  LAR       CB    13    2024_13_LA_NO            0.0
# 46124    2024  LAR       CB    14   2024_14_BUF_LA            0.0
# 50296    2024  NYJ       LB    10  2024_10_NYJ_ARI            0.0
# 51759    2024  SEA       CB     1  2024_01_DEN_SEA            0.0
#
#        defense_snaps                  join_string pfr_player_id  \
# 27837           59.0        Decobie Durant LAR CB      DuraDe01
# 27857           32.0        Decobie Durant LAR CB      DuraDe01
# 27867           29.0        Decobie Durant LAR CB      DuraDe01
# 27875           50.0        Decobie Durant LAR CB      DuraDe01
# 27879           53.0        Decobie Durant LAR CB      DuraDe01
# 33505           73.0          Tariq Woolen SEA CB      WoolTa00
# 33510           54.0          Tariq Woolen SEA CB      WoolTa00
# 33515           66.0          Tariq Woolen SEA CB      WoolTa00
# 33520           76.0          Tariq Woolen SEA CB      WoolTa00
# 33525           65.0          Tariq Woolen SEA CB      WoolTa00
# 33530           61.0          Tariq Woolen SEA CB      WoolTa00
# 33535           67.0          Tariq Woolen SEA CB      WoolTa00
# 33541           26.0          Tariq Woolen SEA CB      WoolTa00
# 33545           87.0          Tariq Woolen SEA CB      WoolTa00
# 33551           54.0          Tariq Woolen SEA CB      WoolTa00
# 33561           66.0          Tariq Woolen SEA CB      WoolTa00
# 33568           71.0          Tariq Woolen SEA CB      WoolTa00
# 36190           75.0       Jartavius Martin WAS S      MartJa04
# 36196           62.0       Jartavius Martin WAS S      MartJa04
# 36199           63.0       Jartavius Martin WAS S      MartJa04
# 36922           31.0            Dee Alford ATL CB      AlfoDe00
# 36926           53.0            Dee Alford ATL CB      AlfoDe00
# 36933           48.0            Dee Alford ATL CB      AlfoDe00
# 36939           38.0            Dee Alford ATL CB      AlfoDe00
# 36950           61.0            Dee Alford ATL CB      AlfoDe00
# 36956           54.0            Dee Alford ATL CB      AlfoDe00
# 36962           69.0            Dee Alford ATL CB      AlfoDe00
# 36970           70.0            Dee Alford ATL CB      AlfoDe00
# 36988           29.0            Dee Alford ATL CB      AlfoDe00
# 36994           40.0            Dee Alford ATL CB      AlfoDe00
# 37000           48.0            Dee Alford ATL CB      AlfoDe00
# 37006           38.0            Dee Alford ATL CB      AlfoDe00
# 37013           72.0            Dee Alford ATL CB      AlfoDe00
# 37193           37.0          Nate Landman ATL LB      LandNa01
# 37209           52.0          Nate Landman ATL LB      LandNa01
# 37212           60.0          Nate Landman ATL LB      LandNa01
# 37215           55.0          Nate Landman ATL LB      LandNa01
# 37218           73.0          Nate Landman ATL LB      LandNa01
# 37221           44.0          Nate Landman ATL LB      LandNa01
# 37224           60.0          Nate Landman ATL LB      LandNa01
# 37239           28.0          Nate Landman ATL LB      LandNa01
# 37242           34.0          Nate Landman ATL LB      LandNa01
# 44945           31.0  Chris Roland-Wallace KCC CB      RolaCh00
# 44985           32.0  Chris Roland-Wallace KCC CB      RolaCh00
# 44989           50.0  Chris Roland-Wallace KCC CB      RolaCh00
# 46049           59.0        Decobie Durant LAR CB      DuraDe01
# 46054           48.0        Decobie Durant LAR CB      DuraDe01
# 46061           70.0        Decobie Durant LAR CB      DuraDe01
# 46066           60.0        Decobie Durant LAR CB      DuraDe01
# 46075           56.0        Decobie Durant LAR CB      DuraDe01
# 46084           44.0        Decobie Durant LAR CB      DuraDe01
# 46090           49.0        Decobie Durant LAR CB      DuraDe01
# 46095           79.0        Decobie Durant LAR CB      DuraDe01
# 46102           53.0        Decobie Durant LAR CB      DuraDe01
# 46109           41.0        Decobie Durant LAR CB      DuraDe01
# 46113           43.0        Decobie Durant LAR CB      DuraDe01
# 46118           70.0        Decobie Durant LAR CB      DuraDe01
# 46124           50.0        Decobie Durant LAR CB      DuraDe01
# 50296           38.0          Sam Eguavoen NYJ LB      EguaSa00
# 51759           69.0          Tariq Woolen SEA CB      WoolTa00
#
#                      player_pfr pfr_position side            player_mfl  \
# 27837              Cobie Durant           CB  DEF        Decobie Durant
# 27857              Cobie Durant           CB  DEF        Decobie Durant
# 27867              Cobie Durant           CB  DEF        Decobie Durant
# 27875              Cobie Durant           CB  DEF        Decobie Durant
# 27879              Cobie Durant           CB  DEF        Decobie Durant
# 33505                Riq Woolen           CB  DEF          Tariq Woolen
# 33510                Riq Woolen           CB  DEF          Tariq Woolen
# 33515                Riq Woolen           CB  DEF          Tariq Woolen
# 33520                Riq Woolen           CB  DEF          Tariq Woolen
# 33525                Riq Woolen           CB  DEF          Tariq Woolen
# 33530                Riq Woolen           CB  DEF          Tariq Woolen
# 33535                Riq Woolen           CB  DEF          Tariq Woolen
# 33541                Riq Woolen           CB  DEF          Tariq Woolen
# 33545                Riq Woolen           CB  DEF          Tariq Woolen
# 33551                Riq Woolen           CB  DEF          Tariq Woolen
# 33561                Riq Woolen           CB  DEF          Tariq Woolen
# 33568                Riq Woolen           CB  DEF          Tariq Woolen
# 36190               Quan Martin           CB  DEF      Jartavius Martin
# 36196               Quan Martin           CB  DEF      Jartavius Martin
# 36199               Quan Martin           CB  DEF      Jartavius Martin
# 36922           DeAundre Alford           CB  DEF            Dee Alford
# 36926           DeAundre Alford           CB  DEF            Dee Alford
# 36933           DeAundre Alford           CB  DEF            Dee Alford
# 36939           DeAundre Alford           CB  DEF            Dee Alford
# 36950           DeAundre Alford           CB  DEF            Dee Alford
# 36956           DeAundre Alford           CB  DEF            Dee Alford
# 36962           DeAundre Alford           CB  DEF            Dee Alford
# 36970           DeAundre Alford           CB  DEF            Dee Alford
# 36988           DeAundre Alford           CB  DEF            Dee Alford
# 36994           DeAundre Alford           CB  DEF            Dee Alford
# 37000           DeAundre Alford           CB  DEF            Dee Alford
# 37006           DeAundre Alford           CB  DEF            Dee Alford
# 37013           DeAundre Alford           CB  DEF            Dee Alford
# 37193            Nathan Landman           LB  DEF          Nate Landman
# 37209            Nathan Landman           LB  DEF          Nate Landman
# 37212            Nathan Landman           LB  DEF          Nate Landman
# 37215            Nathan Landman           LB  DEF          Nate Landman
# 37218            Nathan Landman           LB  DEF          Nate Landman
# 37221            Nathan Landman           LB  DEF          Nate Landman
# 37224            Nathan Landman           LB  DEF          Nate Landman
# 37239            Nathan Landman           LB  DEF          Nate Landman
# 37242            Nathan Landman           LB  DEF          Nate Landman
# 44945  Christian Roland-Wallace           CB  DEF  Chris Roland-Wallace
# 44985  Christian Roland-Wallace           CB  DEF  Chris Roland-Wallace
# 44989  Christian Roland-Wallace           CB  DEF  Chris Roland-Wallace
# 46049              Cobie Durant           CB  DEF        Decobie Durant
# 46054              Cobie Durant           CB  DEF        Decobie Durant
# 46061              Cobie Durant           CB  DEF        Decobie Durant
# 46066              Cobie Durant           CB  DEF        Decobie Durant
# 46075              Cobie Durant           CB  DEF        Decobie Durant
# 46084              Cobie Durant           CB  DEF        Decobie Durant
# 46090              Cobie Durant           CB  DEF        Decobie Durant
# 46095              Cobie Durant           CB  DEF        Decobie Durant
# 46102              Cobie Durant           CB  DEF        Decobie Durant
# 46109              Cobie Durant           CB  DEF        Decobie Durant
# 46113              Cobie Durant           CB  DEF        Decobie Durant
# 46118              Cobie Durant           CB  DEF        Decobie Durant
# 46124              Cobie Durant           CB  DEF        Decobie Durant
# 50296           Samuel Eguavoen           LB  DEF          Sam Eguavoen
# 51759                Riq Woolen           CB  DEF          Tariq Woolen
#
#        offense_rank  offense_thresh  offense_weight  defense_rank  \
# 27837          17.0            29.0             0.0           2.0
# 27857          20.0            24.0             0.0          11.0
# 27867          19.0            19.0             0.0          12.0
# 27875          19.0            17.0             0.0           7.0
# 27879          19.0             4.0             0.0          10.0
# 33505          35.0            29.0             0.0           3.0
# 33510          34.0            32.0             0.0           4.0
# 33515          34.0            34.0             0.0           5.0
# 33520          35.0            24.0             0.0           4.0
# 33525          35.0            24.0             0.0           5.0
# 33530          34.0            39.0             0.0           5.0
# 33535          35.0            26.0             0.0           5.0
# 33541          34.0            20.0             0.0          12.0
# 33545          35.0            29.0             0.0           4.0
# 33551          35.0            27.0             0.0           4.0
# 33561          33.0            26.0             0.0           4.0
# 33568          34.0            22.0             0.0           5.0
# 36190          25.0            24.0             0.0           3.0
# 36196          26.0            27.0             0.0           9.0
# 36199          24.0            23.0             0.0           5.0
# 36922          18.0            23.0             0.0          11.0
# 36926          17.0            16.0             0.0           6.0
# 36933          19.0            19.0             0.0           7.0
# 36939          18.0            21.0             0.0          10.0
# 36950          18.0            29.0             0.0           4.0
# 36956          20.0            18.0             0.0           6.0
# 36962          19.0            30.0             0.0           5.0
# 36970          19.0            26.0             0.0           7.0
# 36988          20.0            33.0             0.0           7.0
# 36994          18.0            35.0             0.0           7.0
# 37000          17.0            24.0             0.0           6.0
# 37006          18.0            30.0             0.0           6.0
# 37013          17.0            30.0             0.0           6.0
# 37193          32.0            23.0             0.0          10.0
# 37209          31.0            29.0             0.0           6.0
# 37212          32.0            18.0             0.0           5.0
# 37215          30.0            30.0             0.0           7.0
# 37218          31.0            26.0             0.0           6.0
# 37221          30.0            38.0             0.0           5.0
# 37224          31.0            26.0             0.0           6.0
# 37239          32.0            30.0             0.0           9.0
# 37242          31.0            30.0             0.0          12.0
# 44945          19.0            23.0             0.0          11.0
# 44985          19.0            32.0             0.0          12.0
# 44989          18.0            28.0             0.0           9.0
# 46049          19.0            25.0             0.0           5.0
# 46054          19.0            26.0             0.0           8.0
# 46061          18.0            26.0             0.0           4.0
# 46066          20.0            13.0             0.0           1.0
# 46075          19.0            17.0             0.0           3.0
# 46084          20.0            16.0             0.0          10.0
# 46090          21.0            30.0             0.0           3.0
# 46095          20.0            29.0             0.0           2.0
# 46102          20.0            13.0             0.0           2.0
# 46109          21.0            19.0             0.0          12.0
# 46113          19.0            19.0             0.0          10.0
# 46118          20.0            20.0             0.0           2.0
# 46124          20.0            35.0             0.0           5.0
# 50296          34.0            20.0             0.0           9.0
# 51759          32.0            32.0             0.0           4.0
#
#        defense_thresh  defense_weight
# 27837            29.0             1.0
# 27857            31.0             1.0
# 27867            29.0             1.0
# 27875            20.0             1.0
# 27879            21.0             1.0
# 33505            38.0             1.0
# 33510            24.0             1.0
# 33515            23.0             1.0
# 33520            43.0             1.0
# 33525            38.0             1.0
# 33530            29.0             1.0
# 33535            31.0             1.0
# 33541            26.0             1.0
# 33545            36.0             1.0
# 33551            30.0             1.0
# 33561            25.0             1.0
# 33568            26.0             1.0
# 36190            35.0             1.0
# 36196            39.0             1.0
# 36199            34.0             1.0
# 36922            31.0             0.5
# 36926            36.0             1.0
# 36933            35.0             1.0
# 36939            37.0             1.0
# 36950            24.0             1.0
# 36956            28.0             1.0
# 36962            33.0             1.0
# 36970            33.0             1.0
# 36988            21.0             1.0
# 36994            29.0             1.0
# 37000            29.0             1.0
# 37006            25.0             1.0
# 37013            34.0             1.0
# 37193            31.0             1.0
# 37209            24.0             1.0
# 37212            28.0             1.0
# 37215            33.0             1.0
# 37218            33.0             1.0
# 37221            24.0             1.0
# 37224            25.0             1.0
# 37239            25.0             1.0
# 37242            34.0             1.0
# 44945            27.0             1.0
# 44985            32.0             1.0
# 44989            40.0             1.0
# 46049            37.0             1.0
# 46054            37.0             1.0
# 46061            30.0             1.0
# 46066            33.0             1.0
# 46075            30.0             1.0
# 46084            40.0             1.0
# 46090            22.0             1.0
# 46095            40.0             1.0
# 46102            33.0             1.0
# 46109            41.0             0.5
# 46113            37.0             1.0
# 46118            30.0             1.0
# 46124            36.0             1.0
# 50296            22.0             1.0
# 51759            40.0             1.0

# %%
df[ (df['player_pfr'] != df['player_mfl']) & (df['offense_weight'] + df['defense_weight'] > 0) ].tail(60)
# Out:
#        season team position  week          game_id  offense_snaps  \
# 33551    2023  SEA       CB    14   2023_14_SEA_SF            0.0
# 33561    2023  SEA       CB    16  2023_16_SEA_TEN            0.0
# 33568    2023  SEA       CB    17  2023_17_PIT_SEA            0.0
# 36190    2023  WAS        S    15   2023_15_WAS_LA            0.0
# 36196    2023  WAS        S    16  2023_16_WAS_NYJ            0.0
# 36199    2023  WAS        S    17   2023_17_SF_WAS            0.0
# 36922    2024  ATL       CB     1  2024_01_PIT_ATL            0.0
# 36926    2024  ATL       CB     2  2024_02_ATL_PHI            0.0
# 36933    2024  ATL       CB     3   2024_03_KC_ATL            0.0
# 36939    2024  ATL       CB     4   2024_04_NO_ATL            0.0
# 36950    2024  ATL       CB     6  2024_06_ATL_CAR            0.0
# 36956    2024  ATL       CB     7  2024_07_SEA_ATL            0.0
# 36962    2024  ATL       CB     8   2024_08_ATL_TB            0.0
# 36970    2024  ATL       CB     9  2024_09_DAL_ATL            0.0
# 36988    2024  ATL       CB    13  2024_13_LAC_ATL            0.0
# 36994    2024  ATL       CB    14  2024_14_ATL_MIN            0.0
# 37000    2024  ATL       CB    15   2024_15_ATL_LV            0.0
# 37006    2024  ATL       CB    16  2024_16_NYG_ATL            0.0
# 37013    2024  ATL       CB    17  2024_17_ATL_WAS            0.0
# 37193    2024  ATL       LB     1  2024_01_PIT_ATL            0.0
# 37209    2024  ATL       LB     6  2024_06_ATL_CAR            0.0
# 37212    2024  ATL       LB     7  2024_07_SEA_ATL            0.0
# 37215    2024  ATL       LB     8   2024_08_ATL_TB            0.0
# 37218    2024  ATL       LB     9  2024_09_DAL_ATL            0.0
# 37221    2024  ATL       LB    10   2024_10_ATL_NO            0.0
# 37224    2024  ATL       LB    11  2024_11_ATL_DEN            0.0
# 37239    2024  ATL       LB    16  2024_16_NYG_ATL            0.0
# 37242    2024  ATL       LB    17  2024_17_ATL_WAS            0.0
# 44945    2024  KCC       CB     8    2024_08_KC_LV            0.0
# 44985    2024  KCC       CB    16   2024_16_HOU_KC            0.0
# 44989    2024  KCC       CB    17   2024_17_KC_PIT            0.0
# 46049    2024  LAR       CB     1   2024_01_LA_DET            0.0
# 46054    2024  LAR       CB     2   2024_02_LA_ARI            0.0
# 46061    2024  LAR       CB     3    2024_03_SF_LA            0.0
# 46066    2024  LAR       CB     4   2024_04_LA_CHI            0.0
# 46075    2024  LAR       CB     5    2024_05_GB_LA            0.0
# 46084    2024  LAR       CB     7    2024_07_LV_LA            0.0
# 46090    2024  LAR       CB     8   2024_08_MIN_LA            0.0
# 46095    2024  LAR       CB     9   2024_09_LA_SEA            0.0
# 46102    2024  LAR       CB    10   2024_10_MIA_LA            0.0
# 46109    2024  LAR       CB    11    2024_11_LA_NE            0.0
# 46113    2024  LAR       CB    12   2024_12_PHI_LA            0.0
# 46118    2024  LAR       CB    13    2024_13_LA_NO            0.0
# 46124    2024  LAR       CB    14   2024_14_BUF_LA            0.0
# 50296    2024  NYJ       LB    10  2024_10_NYJ_ARI            0.0
# 51759    2024  SEA       CB     1  2024_01_DEN_SEA            0.0
# 51763    2024  SEA       CB     2   2024_02_SEA_NE            0.0
# 51767    2024  SEA       CB     3  2024_03_MIA_SEA            0.0
# 51771    2024  SEA       CB     4  2024_04_SEA_DET            0.0
# 51776    2024  SEA       CB     5  2024_05_NYG_SEA            0.0
# 51787    2024  SEA       CB     8  2024_08_BUF_SEA            0.0
# 51791    2024  SEA       CB     9   2024_09_LA_SEA            0.0
# 51795    2024  SEA       CB    11   2024_11_SEA_SF            0.0
# 51799    2024  SEA       CB    12  2024_12_ARI_SEA            0.0
# 51803    2024  SEA       CB    13  2024_13_SEA_NYJ            0.0
# 51807    2024  SEA       CB    14  2024_14_SEA_ARI            0.0
# 51811    2024  SEA       CB    15   2024_15_GB_SEA            0.0
# 51815    2024  SEA       CB    16  2024_16_MIN_SEA            0.0
# 51820    2024  SEA       CB    17  2024_17_SEA_CHI            0.0
# 53207    2024  TBB       LB    14    2024_14_LV_TB            0.0
#
#        defense_snaps                  join_string pfr_player_id  \
# 33551           54.0          Tariq Woolen SEA CB      WoolTa00
# 33561           66.0          Tariq Woolen SEA CB      WoolTa00
# 33568           71.0          Tariq Woolen SEA CB      WoolTa00
# 36190           75.0       Jartavius Martin WAS S      MartJa04
# 36196           62.0       Jartavius Martin WAS S      MartJa04
# 36199           63.0       Jartavius Martin WAS S      MartJa04
# 36922           31.0            Dee Alford ATL CB      AlfoDe00
# 36926           53.0            Dee Alford ATL CB      AlfoDe00
# 36933           48.0            Dee Alford ATL CB      AlfoDe00
# 36939           38.0            Dee Alford ATL CB      AlfoDe00
# 36950           61.0            Dee Alford ATL CB      AlfoDe00
# 36956           54.0            Dee Alford ATL CB      AlfoDe00
# 36962           69.0            Dee Alford ATL CB      AlfoDe00
# 36970           70.0            Dee Alford ATL CB      AlfoDe00
# 36988           29.0            Dee Alford ATL CB      AlfoDe00
# 36994           40.0            Dee Alford ATL CB      AlfoDe00
# 37000           48.0            Dee Alford ATL CB      AlfoDe00
# 37006           38.0            Dee Alford ATL CB      AlfoDe00
# 37013           72.0            Dee Alford ATL CB      AlfoDe00
# 37193           37.0          Nate Landman ATL LB      LandNa01
# 37209           52.0          Nate Landman ATL LB      LandNa01
# 37212           60.0          Nate Landman ATL LB      LandNa01
# 37215           55.0          Nate Landman ATL LB      LandNa01
# 37218           73.0          Nate Landman ATL LB      LandNa01
# 37221           44.0          Nate Landman ATL LB      LandNa01
# 37224           60.0          Nate Landman ATL LB      LandNa01
# 37239           28.0          Nate Landman ATL LB      LandNa01
# 37242           34.0          Nate Landman ATL LB      LandNa01
# 44945           31.0  Chris Roland-Wallace KCC CB      RolaCh00
# 44985           32.0  Chris Roland-Wallace KCC CB      RolaCh00
# 44989           50.0  Chris Roland-Wallace KCC CB      RolaCh00
# 46049           59.0        Decobie Durant LAR CB      DuraDe01
# 46054           48.0        Decobie Durant LAR CB      DuraDe01
# 46061           70.0        Decobie Durant LAR CB      DuraDe01
# 46066           60.0        Decobie Durant LAR CB      DuraDe01
# 46075           56.0        Decobie Durant LAR CB      DuraDe01
# 46084           44.0        Decobie Durant LAR CB      DuraDe01
# 46090           49.0        Decobie Durant LAR CB      DuraDe01
# 46095           79.0        Decobie Durant LAR CB      DuraDe01
# 46102           53.0        Decobie Durant LAR CB      DuraDe01
# 46109           41.0        Decobie Durant LAR CB      DuraDe01
# 46113           43.0        Decobie Durant LAR CB      DuraDe01
# 46118           70.0        Decobie Durant LAR CB      DuraDe01
# 46124           50.0        Decobie Durant LAR CB      DuraDe01
# 50296           38.0          Sam Eguavoen NYJ LB      EguaSa00
# 51759           69.0          Tariq Woolen SEA CB      WoolTa00
# 51763           66.0          Tariq Woolen SEA CB      WoolTa00
# 51767           54.0          Tariq Woolen SEA CB      WoolTa00
# 51771           52.0          Tariq Woolen SEA CB      WoolTa00
# 51776           49.0          Tariq Woolen SEA CB      WoolTa00
# 51787           69.0          Tariq Woolen SEA CB      WoolTa00
# 51791           77.0          Tariq Woolen SEA CB      WoolTa00
# 51795           61.0          Tariq Woolen SEA CB      WoolTa00
# 51799           57.0          Tariq Woolen SEA CB      WoolTa00
# 51803           68.0          Tariq Woolen SEA CB      WoolTa00
# 51807           70.0          Tariq Woolen SEA CB      WoolTa00
# 51811           64.0          Tariq Woolen SEA CB      WoolTa00
# 51815           54.0          Tariq Woolen SEA CB      WoolTa00
# 51820           61.0          Tariq Woolen SEA CB      WoolTa00
# 53207           40.0           Deion Jones TBB LB      JoneVi00
#
#                      player_pfr pfr_position side            player_mfl  \
# 33551                Riq Woolen           CB  DEF          Tariq Woolen
# 33561                Riq Woolen           CB  DEF          Tariq Woolen
# 33568                Riq Woolen           CB  DEF          Tariq Woolen
# 36190               Quan Martin           CB  DEF      Jartavius Martin
# 36196               Quan Martin           CB  DEF      Jartavius Martin
# 36199               Quan Martin           CB  DEF      Jartavius Martin
# 36922           DeAundre Alford           CB  DEF            Dee Alford
# 36926           DeAundre Alford           CB  DEF            Dee Alford
# 36933           DeAundre Alford           CB  DEF            Dee Alford
# 36939           DeAundre Alford           CB  DEF            Dee Alford
# 36950           DeAundre Alford           CB  DEF            Dee Alford
# 36956           DeAundre Alford           CB  DEF            Dee Alford
# 36962           DeAundre Alford           CB  DEF            Dee Alford
# 36970           DeAundre Alford           CB  DEF            Dee Alford
# 36988           DeAundre Alford           CB  DEF            Dee Alford
# 36994           DeAundre Alford           CB  DEF            Dee Alford
# 37000           DeAundre Alford           CB  DEF            Dee Alford
# 37006           DeAundre Alford           CB  DEF            Dee Alford
# 37013           DeAundre Alford           CB  DEF            Dee Alford
# 37193            Nathan Landman           LB  DEF          Nate Landman
# 37209            Nathan Landman           LB  DEF          Nate Landman
# 37212            Nathan Landman           LB  DEF          Nate Landman
# 37215            Nathan Landman           LB  DEF          Nate Landman
# 37218            Nathan Landman           LB  DEF          Nate Landman
# 37221            Nathan Landman           LB  DEF          Nate Landman
# 37224            Nathan Landman           LB  DEF          Nate Landman
# 37239            Nathan Landman           LB  DEF          Nate Landman
# 37242            Nathan Landman           LB  DEF          Nate Landman
# 44945  Christian Roland-Wallace           CB  DEF  Chris Roland-Wallace
# 44985  Christian Roland-Wallace           CB  DEF  Chris Roland-Wallace
# 44989  Christian Roland-Wallace           CB  DEF  Chris Roland-Wallace
# 46049              Cobie Durant           CB  DEF        Decobie Durant
# 46054              Cobie Durant           CB  DEF        Decobie Durant
# 46061              Cobie Durant           CB  DEF        Decobie Durant
# 46066              Cobie Durant           CB  DEF        Decobie Durant
# 46075              Cobie Durant           CB  DEF        Decobie Durant
# 46084              Cobie Durant           CB  DEF        Decobie Durant
# 46090              Cobie Durant           CB  DEF        Decobie Durant
# 46095              Cobie Durant           CB  DEF        Decobie Durant
# 46102              Cobie Durant           CB  DEF        Decobie Durant
# 46109              Cobie Durant           CB  DEF        Decobie Durant
# 46113              Cobie Durant           CB  DEF        Decobie Durant
# 46118              Cobie Durant           CB  DEF        Decobie Durant
# 46124              Cobie Durant           CB  DEF        Decobie Durant
# 50296           Samuel Eguavoen           LB  DEF          Sam Eguavoen
# 51759                Riq Woolen           CB  DEF          Tariq Woolen
# 51763                Riq Woolen           CB  DEF          Tariq Woolen
# 51767                Riq Woolen           CB  DEF          Tariq Woolen
# 51771                Riq Woolen           CB  DEF          Tariq Woolen
# 51776                Riq Woolen           CB  DEF          Tariq Woolen
# 51787                Riq Woolen           CB  DEF          Tariq Woolen
# 51791                Riq Woolen           CB  DEF          Tariq Woolen
# 51795                Riq Woolen           CB  DEF          Tariq Woolen
# 51799                Riq Woolen           CB  DEF          Tariq Woolen
# 51803                Riq Woolen           CB  DEF          Tariq Woolen
# 51807                Riq Woolen           CB  DEF          Tariq Woolen
# 51811                Riq Woolen           CB  DEF          Tariq Woolen
# 51815                Riq Woolen           CB  DEF          Tariq Woolen
# 51820                Riq Woolen           CB  DEF          Tariq Woolen
# 53207                  Vi Jones           LB  DEF           Deion Jones
#
#        offense_rank  offense_thresh  offense_weight  defense_rank  \
# 33551          35.0            27.0             0.0           4.0
# 33561          33.0            26.0             0.0           4.0
# 33568          34.0            22.0             0.0           5.0
# 36190          25.0            24.0             0.0           3.0
# 36196          26.0            27.0             0.0           9.0
# 36199          24.0            23.0             0.0           5.0
# 36922          18.0            23.0             0.0          11.0
# 36926          17.0            16.0             0.0           6.0
# 36933          19.0            19.0             0.0           7.0
# 36939          18.0            21.0             0.0          10.0
# 36950          18.0            29.0             0.0           4.0
# 36956          20.0            18.0             0.0           6.0
# 36962          19.0            30.0             0.0           5.0
# 36970          19.0            26.0             0.0           7.0
# 36988          20.0            33.0             0.0           7.0
# 36994          18.0            35.0             0.0           7.0
# 37000          17.0            24.0             0.0           6.0
# 37006          18.0            30.0             0.0           6.0
# 37013          17.0            30.0             0.0           6.0
# 37193          32.0            23.0             0.0          10.0
# 37209          31.0            29.0             0.0           6.0
# 37212          32.0            18.0             0.0           5.0
# 37215          30.0            30.0             0.0           7.0
# 37218          31.0            26.0             0.0           6.0
# 37221          30.0            38.0             0.0           5.0
# 37224          31.0            26.0             0.0           6.0
# 37239          32.0            30.0             0.0           9.0
# 37242          31.0            30.0             0.0          12.0
# 44945          19.0            23.0             0.0          11.0
# 44985          19.0            32.0             0.0          12.0
# 44989          18.0            28.0             0.0           9.0
# 46049          19.0            25.0             0.0           5.0
# 46054          19.0            26.0             0.0           8.0
# 46061          18.0            26.0             0.0           4.0
# 46066          20.0            13.0             0.0           1.0
# 46075          19.0            17.0             0.0           3.0
# 46084          20.0            16.0             0.0          10.0
# 46090          21.0            30.0             0.0           3.0
# 46095          20.0            29.0             0.0           2.0
# 46102          20.0            13.0             0.0           2.0
# 46109          21.0            19.0             0.0          12.0
# 46113          19.0            19.0             0.0          10.0
# 46118          20.0            20.0             0.0           2.0
# 46124          20.0            35.0             0.0           5.0
# 50296          34.0            20.0             0.0           9.0
# 51759          32.0            32.0             0.0           4.0
# 51763          32.0            25.0             0.0           5.0
# 51767          31.0            28.0             0.0           5.0
# 51771          31.0            38.0             0.0           4.0
# 51776          31.0            21.0             0.0          10.0
# 51787          32.0            23.0             0.0           6.0
# 51791          33.0            35.0             0.0           5.0
# 51795          33.0            22.0             0.0           5.0
# 51799          34.0            29.0             0.0           5.0
# 51803          33.0            29.0             0.0           5.0
# 51807          34.0            24.0             0.0           5.0
# 51811          35.0            24.0             0.0           3.0
# 51815          33.0            21.0             0.0           5.0
# 51820          33.0            18.0             0.0           5.0
# 53207          22.0            25.0             0.0          11.0
#
#        defense_thresh  defense_weight
# 33551            30.0             1.0
# 33561            25.0             1.0
# 33568            26.0             1.0
# 36190            35.0             1.0
# 36196            39.0             1.0
# 36199            34.0             1.0
# 36922            31.0             0.5
# 36926            36.0             1.0
# 36933            35.0             1.0
# 36939            37.0             1.0
# 36950            24.0             1.0
# 36956            28.0             1.0
# 36962            33.0             1.0
# 36970            33.0             1.0
# 36988            21.0             1.0
# 36994            29.0             1.0
# 37000            29.0             1.0
# 37006            25.0             1.0
# 37013            34.0             1.0
# 37193            31.0             1.0
# 37209            24.0             1.0
# 37212            28.0             1.0
# 37215            33.0             1.0
# 37218            33.0             1.0
# 37221            24.0             1.0
# 37224            25.0             1.0
# 37239            25.0             1.0
# 37242            34.0             1.0
# 44945            27.0             1.0
# 44985            32.0             1.0
# 44989            40.0             1.0
# 46049            37.0             1.0
# 46054            37.0             1.0
# 46061            30.0             1.0
# 46066            33.0             1.0
# 46075            30.0             1.0
# 46084            40.0             1.0
# 46090            22.0             1.0
# 46095            40.0             1.0
# 46102            33.0             1.0
# 46109            41.0             0.5
# 46113            37.0             1.0
# 46118            30.0             1.0
# 46124            36.0             1.0
# 50296            22.0             1.0
# 51759            40.0             1.0
# 51763            37.0             1.0
# 51767            33.0             1.0
# 51771            23.0             1.0
# 51776            41.0             1.0
# 51787            30.0             1.0
# 51791            42.0             1.0
# 51795            33.0             1.0
# 51799            30.0             1.0
# 51803            35.0             1.0
# 51807            38.0             1.0
# 51811            31.0             1.0
# 51815            35.0             1.0
# 51820            32.0             1.0
# 53207            38.0             1.0
