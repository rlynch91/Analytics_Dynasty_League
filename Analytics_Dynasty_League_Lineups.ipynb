# %%
# Import python packages
import numpy as np
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process as fwprocess
import rpy2
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri

# %%
# Can uncomment to install R packages as needed
#utils = importr('utils')
#utils.install_packages('nflreadr')
#utils.install_packages('ffscrapr')

# %%
# Import R packages
nflreadr = importr('nflreadr')
ffscrapr = importr('ffscrapr')

# %%
# Config for the calculation
mfl_id = 60206  #MFL id for league
seasons = [2023,2022,2021]  #Seasons to collect data for
max_week = 17  #Maximum week number to include in calculation
num_off = 7  #Number of offensive players to include in calculation for each game
num_def = 12  #Number of defensive  players to include in calculation for each game
save_label = 'Analytics_Dynasty_League_2024'  #Where to save results

# %%
# A mapping from PFR team names to MFL team names

###
team_dic = {
    'ARI' : 'ARI',
    'ATL' : 'ATL',
    'BAL' : 'BAL',
    'BUF' : 'BUF',
    'CAR' : 'CAR',
    'CHI' : 'CHI',
    'CIN' : 'CIN',
    'CLE' : 'CLE',
    'DAL' : 'DAL',
    'DEN' : 'DEN',
    'DET' : 'DET',
    'GB' : 'GBP',
    'HOU' : 'HOU',
    'IND' : 'IND',
    'JAX' : 'JAC',
    'KC' : 'KCC',
    'LA' : 'LAR',
    'LAC' : 'LAC',
    'LV' : 'LVR',
    'MIA' : 'MIA',
    'MIN' : 'MIN',
    'NE' : 'NEP',
    'NO' : 'NOS',
    'NYG' : 'NYG',
    'NYJ' : 'NYJ',
    'PHI' : 'PHI',
    'PIT' : 'PIT',
    'SEA' : 'SEA',
    'SF' : 'SFO',
    'TB' : 'TBB',
    'TEN' : 'TEN',
    'WAS' : 'WAS',
}

# %%
# Mappings for positions, both to consider which positions to drop from the analysis and to cleanup PFR positions a bit

###
snap_side_map = {
    'C' : 'DROP',
    'CB' : 'DEF',
    'DB' : 'DEF',
    'DE' : 'DEF',
    'DT' : 'DEF',
    'FB' : 'DROP',  #Change to OFF if want to include FBs
    'FS' : 'DEF',
    'G' : 'DROP',
    'K' : 'DROP',
    'LB' : 'DEF',
    'LS' : 'DROP',
    'NT' : 'DEF',
    'P' : 'DROP',
    'QB' : 'OFF',
    'RB' : 'OFF',
    'SS' : 'DEF',
    'T' : 'DROP',
    'TE' : 'OFF',
    'WR' : 'OFF',
}

snap_position_map = {
    'CB' : 'CB',
    'DB' : 'S',
    'DE' : 'DE',
    'DT' : 'DT',
    'FB' : 'RB',
    'FS' : 'S',
    'LB' : 'LB',
    'NT' : 'DT',
    'QB' : 'QB',
    'RB' : 'RB',
    'SS' : 'S',
    'TE' : 'TE',
    'WR' : 'WR',
}

###
pos_side_map = {
    'CB' : 'DEF',
    'Coach' : 'DROP',
    'DE' : 'DEF',
    'DT' : 'DEF',
    'Def' : 'DROP',
    'LB' : 'DEF',
    'Off' : 'DROP',
    'PK' : 'DROP',
    'PN' : 'DROP',
    'QB' : 'OFF',
    'RB' : 'OFF',
    'S' : 'DEF',
    'ST' : 'DROP',
    'TE' : 'OFF',
    'TMDB' : 'DROP',
    'TMDL' : 'DROP',
    'TMLB' : 'DROP',
    'TMPK' : 'DROP',
    'TMPN' : 'DROP',
    'TMQB' : 'DROP',
    'TMRB' : 'DROP',
    'TMTE' : 'DROP',
    'TMWR' : 'DROP',
    'WR' : 'OFF',
    'XX' : 'DROP'}

# %%
# Scrape snap counts from PFR and convert to pandas df
snap_df_r = nflreadr.load_snap_counts(ro.IntVector(seasons))

with (ro.default_converter + pandas2ri.converter).context():
  snap_df = ro.conversion.get_conversion().rpy2py(snap_df_r)

# Cleanup some of the data
snap_df['team'] = snap_df['team'].apply(lambda x: team_dic[x])
snap_df['side'] = snap_df['position'].apply(lambda x: snap_side_map[x])

snap_df = snap_df[ snap_df['side'] != 'DROP' ]

snap_df['position'] = snap_df['position'].apply(lambda x: snap_position_map[x])
snap_df['player_pfr'] = snap_df['player'].apply(lambda x: nflreadr.clean_player_names(x, convert_lastfirst=False)[0])
snap_df['join_string'] = snap_df['player_pfr'] + " " + snap_df['team'] + " " + snap_df['position']

snap_df
# Out:
# Note: nflreadr caches (i.e., stores a saved version) data by default.
# If you expect different output try one of the following:
# ℹ Restart your R Session or
# ℹ Run `nflreadr::.clear_cache()`.
# To disable this warning, run `options(nflreadr.verbose = FALSE)` or add it to your .Rprofile
# This message is displayed once every 8 hours.
#                game_id   pfr_game_id  season game_type  week  \
# 4      2023_01_ARI_WAS  202309100was    2023       REG     1
# 7      2023_01_ARI_WAS  202309100was    2023       REG     1
# 8      2023_01_ARI_WAS  202309100was    2023       REG     1
# 9      2023_01_ARI_WAS  202309100was    2023       REG     1
# 10     2023_01_ARI_WAS  202309100was    2023       REG     1
# ...                ...           ...     ...       ...   ...
# 79300   2021_22_LA_CIN  202202130cin    2021        SB    22
# 79301   2021_22_LA_CIN  202202130cin    2021        SB    22
# 79302   2021_22_LA_CIN  202202130cin    2021        SB    22
# 79303   2021_22_LA_CIN  202202130cin    2021        SB    22
# 79304   2021_22_LA_CIN  202202130cin    2021        SB    22
#
#                    player pfr_player_id position team opponent  offense_snaps  \
# 4              Sam Howell      HoweSa00       QB  WAS      ARI           71.0
# 7          Terry McLaurin      McLaTe00       WR  WAS      ARI           63.0
# 8            Jahan Dotson      DotsJa00       WR  WAS      ARI           62.0
# 9            Logan Thomas      ThomLo00       TE  WAS      ARI           58.0
# 10          Curtis Samuel      SamuCu00       WR  WAS      ARI           46.0
# ...                   ...           ...      ...  ...      ...            ...
# 79300  Christian Rozeboom      RozeCh00       LB  LAR      CIN            0.0
# 79301        Jake Gervase      GervJa00        S  LAR      CIN            0.0
# 79302       Travin Howard      HowaTr00       LB  LAR      CIN            0.0
# 79303         Grant Haley      HaleGr00       CB  LAR      CIN            0.0
# 79304     Terrell Burgess      BurgTe00        S  LAR      CIN            0.0
#
#        offense_pct  defense_snaps  defense_pct  st_snaps  st_pct side  \
# 4             1.00            0.0          0.0       0.0    0.00  OFF
# 7             0.89            0.0          0.0       0.0    0.00  OFF
# 8             0.87            0.0          0.0       0.0    0.00  OFF
# 9             0.82            0.0          0.0       0.0    0.00  OFF
# 10            0.65            0.0          0.0       0.0    0.00  OFF
# ...            ...            ...          ...       ...     ...  ...
# 79300         0.00            0.0          0.0      22.0    0.73  DEF
# 79301         0.00            0.0          0.0      22.0    0.73  DEF
# 79302         0.00            0.0          0.0      22.0    0.73  DEF
# 79303         0.00            0.0          0.0      22.0    0.73  DEF
# 79304         0.00            0.0          0.0      16.0    0.53  DEF
#
#                player_pfr                join_string
# 4              Sam Howell          Sam Howell WAS QB
# 7          Terry McLaurin      Terry McLaurin WAS WR
# 8            Jahan Dotson        Jahan Dotson WAS WR
# 9            Logan Thomas        Logan Thomas WAS TE
# 10          Curtis Samuel       Curtis Samuel WAS WR
# ...                   ...                        ...
# 79300  Christian Rozeboom  Christian Rozeboom LAR LB
# 79301        Jake Gervase         Jake Gervase LAR S
# 79302       Travin Howard       Travin Howard LAR LB
# 79303         Grant Haley         Grant Haley LAR CB
# 79304     Terrell Burgess      Terrell Burgess LAR S
#
# [60702 rows x 19 columns]

# %%
# Dict to store data for each season
pos_df = {}

for s in seasons:
    # Scrape player positions from MFL and convert to pandas df
    mfl = ffscrapr.mfl_connect(season=s, league_id=mfl_id)
    
    pos_df_r = ffscrapr.mfl_players(mfl)
    
    with (ro.default_converter + pandas2ri.converter).context():
      pos_df[s] = ro.conversion.get_conversion().rpy2py(pos_df_r)

    # Cleanup some of the data
    pos_df[s]['season'] = s
    pos_df[s]['side'] = pos_df[s]['pos'].apply(lambda x: pos_side_map[x])

    pos_df[s] = pos_df[s][ pos_df[s]['side'] != 'DROP' ]
    
    pos_df[s]['player_mfl'] = pos_df[s]['player_name'].apply(lambda x: nflreadr.clean_player_names(x, convert_lastfirst=True)[0])
    pos_df[s]['join_string'] = pos_df[s]['player_mfl'] + " " + pos_df[s]['team'] + " " + pos_df[s]['pos']

# Merge seasons to single df
pos_df = pd.concat(pos_df, ignore_index=True)

# Sort by id and season for cleaner display
pos_df = pos_df.set_index(['player_id','season']).sort_index(level=[0,1],ascending=[True,True]).reset_index()

# Save a copy of positions
pos_df[['player_id','player_mfl','season','team','side','pos','join_string']].to_csv(f'{save_label}_Positions.csv', index=False)

pos_df
# Out:
#      player_id  season            player_name pos   age team         status  \
# 0         0800    2022  Weatherford, Sterling   S   NaN  IND              R
# 1         0802    2022           Krull, Lucas  TE   NaN  NOS              R
# 2         0803    2022          Vilain, Luiji  DE   NaN  MIN              R
# 3         0806    2021          Brown, Shakur  CB   NaN  PIT              R
# 4         0808    2021       Griffin, Olaijah  CB   NaN  BUF              R
# ...        ...     ...                    ...  ..   ...  ...            ...
# 6902      9966    2021          Jones, Reshad   S  36.0   FA  NA_character_
# 6903      9988    2021         Brown, Antonio  WR  35.6   FA  NA_character_
# 6904      9988    2022         Brown, Antonio  WR  35.6   FA  NA_character_
# 6905      9988    2023         Brown, Antonio  WR  35.6   FA  NA_character_
# 6906      9992    2021              Webb, Joe  QB  37.3   FA  NA_character_
#
#          draft_team     draft_year     draft_pick  ...                nfl_id  \
# 0     NA_character_  NA_character_  NA_character_  ...         NA_character_
# 1     NA_character_  NA_character_  NA_character_  ...         NA_character_
# 2     NA_character_  NA_character_  NA_character_  ...         NA_character_
# 3     NA_character_  NA_character_  NA_character_  ...         NA_character_
# 4     NA_character_  NA_character_  NA_character_  ...         NA_character_
# ...             ...            ...            ...  ...                   ...
# 6902            MIA           2010             32  ...    reshadjones/496739
# 6903            PIT           2010             26  ...  antoniobrown/2508061
# 6904            PIT           2010             26  ...  antoniobrown/2508061
# 6905            PIT           2010             26  ...  antoniobrown/2508061
# 6906            MIN           2010             30  ...       joewebb/1037347
#
#      twitter_username         weight         jersey           college  \
# 0       NA_character_  NA_character_  NA_character_     NA_character_
# 1       NA_character_  NA_character_  NA_character_     NA_character_
# 2       NA_character_  NA_character_  NA_character_     NA_character_
# 3       NA_character_  NA_character_  NA_character_     NA_character_
# 4       NA_character_  NA_character_  NA_character_     NA_character_
# ...               ...            ...            ...               ...
# 6902     reshadjones9            215             20           Georgia
# 6903   AntonioBrown84            185             81  Central Michigan
# 6904   AntonioBrown84            185             81  Central Michigan
# 6905   AntonioBrown84            185             81  Central Michigan
# 6906       JoeWebb_14            230             14               UAB
#
#              height birthdate side            player_mfl  \
# 0     NA_character_       NaN  DEF  Sterling Weatherford
# 1     NA_character_       NaN  OFF           Lucas Krull
# 2     NA_character_       NaN  DEF          Luiji Vilain
# 3     NA_character_       NaN  DEF          Shakur Brown
# 4     NA_character_       NaN  DEF       Olaijah Griffin
# ...             ...       ...  ...                   ...
# 6902             73    6629.0  DEF          Reshad Jones
# 6903             70    6765.0  OFF         Antonio Brown
# 6904             70    6765.0  OFF         Antonio Brown
# 6905             70    6765.0  OFF         Antonio Brown
# 6906             76    6161.0  OFF              Joe Webb
#
#                      join_string
# 0     Sterling Weatherford IND S
# 1             Lucas Krull NOS TE
# 2            Luiji Vilain MIN DE
# 3            Shakur Brown PIT CB
# 4         Olaijah Griffin BUF CB
# ...                          ...
# 6902           Reshad Jones FA S
# 6903         Antonio Brown FA WR
# 6904         Antonio Brown FA WR
# 6905         Antonio Brown FA WR
# 6906              Joe Webb FA QB
#
# [6907 rows x 29 columns]

# %%
###
def GetClosestJoinString(other_df, this_js):
    # Return closest matching join string using fuzzy matching
    return fwprocess.extract(this_js, other_df['join_string'], scorer=fuzz.ratio)[0][0]

def GetClosestJoinScore(other_df, this_js):
    # Return score of closest match using fuzzy matching
    return fwprocess.extract(this_js, other_df['join_string'], scorer=fuzz.ratio)[0][1]

# %%
# Initialize merged df from snap data
df = snap_df[['game_id','season','week','pfr_player_id','player_pfr','team','position','side','join_string','offense_snaps','defense_snaps']].copy()

# Filter out weeks above max week
df = df[ df['week'] <= max_week ]

# Merge in positions using fuzzy string matching, considering each season and side of ball separately
df = df.set_index(['pfr_player_id','season','week']).sort_index(level=[0,1,2],ascending=[True,True,True])

for s in seasons:
    for side in ['OFF','DEF']:
        print(s,side)

        # Constrain data to this season and side of ball
        tmp_snap_df = snap_df[ (snap_df['season'] == s) & (snap_df['side'] == side) ]
        tmp_snap_df = tmp_snap_df.set_index(['pfr_player_id','season','week']).sort_index(level=[0,1,2],ascending=[True,True,True])
        tmp_snap_df = tmp_snap_df.groupby(['pfr_player_id','season']).tail(1).droplevel(2)

        tmp_pos_df = pos_df[ (pos_df['season'] == s) & (pos_df['side'] == side) ]

        # Fill the df with the closest matching join_string found by the fuzzy matching
        df.loc[ (df.index.get_level_values(1) == s) & (df['side'] == side), 'join_string'] = tmp_snap_df['join_string'].apply(lambda x: GetClosestJoinString(tmp_pos_df, x))

df = df.reset_index()

# With common join strings now in hand, we can merge in the pfl position and player data from MFL
df = df.set_index(['join_string','season']).sort_index(level=[0,1],ascending=[True,True])
df = df.join( pos_df.set_index(['join_string','season']).sort_index(level=[0,1],ascending=[True,True])[['pos','player_mfl']] )

df = df.reset_index()

# Rename the position columns
df = df.rename(columns={'position':'pfr_position'})
df = df.rename(columns={'pos':'position'})

# Find the per-game snap ranks for each player, assign qualifying players weight of 1, and break ties at the boundary with fractional weight
df = df.set_index(['game_id','team']).sort_index(level=[0,1],ascending=[True,True])

df['offense_rank'] = df.groupby(['game_id','team']).apply(lambda x: x['offense_snaps'].rank(method='first',ascending=False)).values  #Snap rank
df['offense_thresh'] = df.groupby(['game_id','team']).apply(lambda x: x['offense_snaps'][ x['offense_rank'] == num_off ].values[0])  #Snap boundary
df['offense_weight'] = ( (df['offense_rank'] <= num_off).values | (df['offense_snaps'] == df['offense_thresh']).values ).astype(float)  #Initial weights
thresh_inds = df['offense_snaps'] == df['offense_thresh']
df.loc[ thresh_inds, 'offense_weight' ] = df[thresh_inds].groupby(['game_id','team']).apply(lambda x: np.sum(x['offense_rank'] <= num_off) / len(x) )  #Normalize weights by breaking ties

df['defense_rank'] = df.groupby(['game_id','team']).apply(lambda x: x['defense_snaps'].rank(method='first',ascending=False)).values  #Snap rank
df['defense_thresh'] = df.groupby(['game_id','team']).apply(lambda x: x['defense_snaps'][ x['defense_rank'] == num_def ].values[0])  #Snap boundary
df['defense_weight'] = ( (df['defense_rank'] <= num_def).values | (df['defense_snaps'] == df['defense_thresh']).values ).astype(float)  #Initial weights
thresh_inds = df['defense_snaps'] == df['defense_thresh']
df.loc[ thresh_inds, 'defense_weight' ] = df[thresh_inds].groupby(['game_id','team']).apply(lambda x: np.sum(x['defense_rank'] <= num_def) / len(x) )  #Normalize weights by breaking ties

df = df.reset_index()

# Sort by season, week, game_id, and team for cleaner display
df = df.set_index(['season','week','game_id','team']).sort_index(level=[0,1,2,3],ascending=[True,True,True,True]).reset_index()

# Save a copy of the raw data
df.to_csv(f'{save_label}_Raw.csv', index=False)

df
# Out:
# 2023 OFF
# 2023 DEF
# 2022 OFF
# 2022 DEF
# 2021 OFF
# 2021 DEF
#        season  week          game_id team              join_string  \
# 0        2021     1  2021_01_ARI_TEN  ARI          AJ Green ARI WR
# 1        2021     1  2021_01_ARI_TEN  ARI  Antonio Hamilton ARI CB
# 2        2021     1  2021_01_ARI_TEN  ARI        Budda Baker ARI S
# 3        2021     1  2021_01_ARI_TEN  ARI      Byron Murphy ARI CB
# 4        2021     1  2021_01_ARI_TEN  ARI    Chandler Jones ARI DE
# ...       ...   ...              ...  ...                      ...
# 54563    2023    17  2023_17_TEN_HOU  TEN        Tae Crowder FA LB
# 54564    2023    17  2023_17_TEN_HOU  TEN    Terrell Edmunds TEN S
# 54565    2023    17  2023_17_TEN_HOU  TEN     Treylon Burks TEN WR
# 54566    2023    17  2023_17_TEN_HOU  TEN      Tyjae Spears TEN RB
# 54567    2023    17  2023_17_TEN_HOU  TEN        Will Levis TEN QB
#
#       pfr_player_id        player_pfr pfr_position side  offense_snaps  \
# 0          GreeA.00          AJ Green           WR  OFF           55.0
# 1          HamiAn01  Antonio Hamilton           CB  DEF            0.0
# 2          BakeBu00       Budda Baker            S  DEF            0.0
# 3          MurpBy00      Byron Murphy           CB  DEF            0.0
# 4          JoneCh03    Chandler Jones           LB  DEF            0.0
# ...             ...               ...          ...  ...            ...
# 54563      CrowTa00       Tae Crowder           LB  DEF            0.0
# 54564      EdmuTe00   Terrell Edmunds            S  DEF            0.0
# 54565      BurkTr00     Treylon Burks           WR  OFF           45.0
# 54566      SpeaTy00      Tyjae Spears           RB  OFF           34.0
# 54567      LeviWi00        Will Levis           QB  OFF           13.0
#
#        defense_snaps position        player_mfl  offense_rank  offense_thresh  \
# 0                0.0       WR          AJ Green           3.0            34.0
# 1                3.0       CB  Antonio Hamilton          13.0            34.0
# 2               61.0        S       Budda Baker          14.0            34.0
# 3               58.0       CB      Byron Murphy          15.0            34.0
# 4               48.0       DE    Chandler Jones          16.0            34.0
# ...              ...      ...               ...           ...             ...
# 54563            0.0       LB       Tae Crowder          35.0            23.0
# 54564           10.0        S   Terrell Edmunds          36.0            23.0
# 54565            0.0       WR     Treylon Burks           2.0            23.0
# 54566            0.0       RB      Tyjae Spears           6.0            23.0
# 54567            0.0       QB        Will Levis           8.0            23.0
#
#        offense_weight  defense_rank  defense_thresh  defense_weight
# 0                 1.0          24.0            22.0             0.0
# 1                 0.0          21.0            22.0             0.0
# 2                 0.0           1.0            22.0             1.0
# 3                 0.0           3.0            22.0             1.0
# 4                 0.0           8.0            22.0             1.0
# ...               ...           ...             ...             ...
# 54563             0.0          33.0            28.0             0.0
# 54564             0.0          18.0            28.0             0.0
# 54565             1.0          34.0            28.0             0.0
# 54566             1.0          35.0            28.0             0.0
# 54567             0.0          36.0            28.0             0.0
#
# [54568 rows x 19 columns]

# %%
# Calculate the mean value for each season-team-position by summing over weights and dividing by number of games
df = df.set_index(['season','team','position']).sort_index(level=[0,1,2],ascending=[True,True,True])

result_off = df['offense_weight'].groupby(['season','team','position']).sum() / df.groupby(['season','team']).apply(lambda x: len(set(x['week'])))
result_off = result_off[ result_off >= 0.1 ]

result_def = df['defense_weight'].groupby(['season','team','position']).sum() / df.groupby(['season','team']).apply(lambda x: len(set(x['week'])))
result_def = result_def[ result_def >= 0.1 ]

df = df.reset_index()

# Pivot results out to columns to put into a nice tabular form
result_off = result_off.unstack(level=-1)
result_def = result_def.unstack(level=-1)

# Calculate values for DL and DB positions
result_def['DL'] = result_def['DT'] + result_def['DE']
result_def['DB'] = result_def['CB'] + result_def['S']

# Cleanup the table, listing the sorted values and season-teams for each position
result_dic = {}

for c in ['QB','RB','WR','TE']:
    tmp_df = result_off[c].reset_index()
    
    tmp_df[f'{c} Team'] = tmp_df['season'].map(str) + " " + tmp_df['team']
    tmp_df = tmp_df[[c, f'{c} Team']].rename(columns={c:f'{c} Value'})
    tmp_df = tmp_df.sort_values(f'{c} Value', ascending=False).reset_index(drop=True)

    result_dic[c] = tmp_df

for c in ['DT','DE','LB','CB','S','DL','DB']:
    tmp_df = result_def[c].reset_index()
    
    tmp_df[f'{c} Team'] = tmp_df['season'].map(str) + " " + tmp_df['team']
    tmp_df = tmp_df[[c, f'{c} Team']].rename(columns={c:f'{c} Value'})
    tmp_df = tmp_df.sort_values(f'{c} Value', ascending=False).reset_index(drop=True)

    result_dic[c] = tmp_df

# Save the table to a csv
result = pd.concat(result_dic, axis=1, ignore_index=False)
result.columns = result.columns.droplevel(0)

result.to_csv(f'{save_label}_Lineups.csv', index=False)

# %%
# Full results
result
# Out:
#     QB Value   QB Team  RB Value   RB Team  WR Value   WR Team  TE Value  \
# 0     1.3750  2021 DEN    1.6875  2022 CLE  3.625000  2023 TBB   2.53125
# 1     1.2500  2021 NOS    1.6250  2022 DAL  3.593750  2023 DAL   2.34375
# 2     1.1250  2023 NOS    1.6250  2022 LVR  3.562500  2023 BAL   2.09375
# 3     1.1250  2021 HOU    1.6250  2023 CHI  3.531250  2022 CHI   2.09375
# 4     1.0625  2023 ATL    1.6250  2023 PHI  3.500000  2021 ARI   2.09375
# ..       ...       ...       ...       ...       ...       ...       ...
# 91    1.0000  2022 JAC    1.0000  2021 PIT  2.562500  2021 DEN   1.15625
# 92    1.0000  2022 IND    1.0000  2021 NEP  2.520833  2022 ATL   1.12500
# 93    1.0000  2022 HOU    1.0000  2023 DAL  2.406250  2021 MIA   1.12500
# 94    1.0000  2022 GBP    1.0000  2023 LAC  2.406250  2022 BAL   1.06250
# 95    1.0000  2022 LAC    1.0000  2023 JAC  2.156250  2023 ATL   1.06250
#
#      TE Team  DT Value   DT Team  ...  LB Value   LB Team  CB Value   CB Team  \
# 0   2023 ATL  3.250000  2021 SEA  ...   2.93750  2022 LAC  3.625000  2022 PHI
# 1   2021 MIA  3.187500  2023 ATL  ...   2.87500  2022 DAL  3.531250  2022 IND
# 2   2021 LAC  3.156250  2023 CAR  ...   2.81250  2022 ARI  3.500000  2022 CAR
# 3   2022 TEN  3.125000  2021 WAS  ...   2.75000  2023 BAL  3.437500  2023 TBB
# 4   2022 BAL  3.125000  2022 ARI  ...   2.71875  2022 NYJ  3.433333  2022 BUF
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 91  2023 MIA  1.562500  2021 DAL  ...   1.71875  2023 CAR  2.312500  2022 ARI
# 92  2022 LAR  1.531250  2021 SFO  ...   1.68750  2023 LAR  2.312500  2022 SFO
# 93  2021 ARI  1.510417  2021 NOS  ...   1.62500  2021 LAR  2.218750  2023 MIN
# 94  2023 BAL  1.437500  2023 DAL  ...   1.59375  2023 MIN  2.187500  2022 BAL
# 95  2021 BUF  1.312500  2022 DAL  ...   1.31250  2023 DAL  2.187500  2023 DET
#
#     S Value    S Team  DL Value   DL Team  DB Value   DB Team
# 0    3.6250  2023 DAL  5.500000  2022 JAC  6.625000  2023 DAL
# 1    3.2500  2021 NEP  5.406250  2023 CAR  5.875000  2022 DAL
# 2    3.0000  2022 BAL  5.375000  2022 MIA  5.687500  2022 NEP
# 3    3.0000  2023 MIN  5.343750  2021 JAC  5.687500  2021 SFO
# 4    2.9375  2022 NEP  5.312500  2022 ATL  5.656250  2021 NOS
# ..      ...       ...       ...       ...       ...       ...
# 91   1.6250  2022 IND  4.197917  2021 NOS  4.687500  2021 SEA
# 92   1.5625  2021 HOU  4.187500  2021 DAL  4.562500  2022 ATL
# 93   1.5625  2023 TBB  4.187500  2022 LAC  4.541667  2022 MIA
# 94   1.4375  2021 BAL  4.062500  2023 DAL  4.437500  2022 JAC
# 95   1.3750  2022 PHI  3.250000  2022 DAL  4.250000  2022 ARI
#
# [96 rows x 22 columns]

# %%
# Team 2
result.iloc[1]
# Out:
# QB Value        1.25
# QB Team     2021 NOS
# RB Value       1.625
# RB Team     2022 DAL
# WR Value     3.59375
# WR Team     2023 DAL
# TE Value     2.34375
# TE Team     2021 MIA
# DT Value      3.1875
# DT Team     2023 ATL
# DE Value    3.114583
# DE Team     2022 KCC
# LB Value       2.875
# LB Team     2022 DAL
# CB Value     3.53125
# CB Team     2022 IND
# S Value         3.25
# S Team      2021 NEP
# DL Value     5.40625
# DL Team     2023 CAR
# DB Value       5.875
# DB Team     2022 DAL
# Name: 1, dtype: object

# %%
# Team 48 (half of median)
result.iloc[47]
# Out:
# QB Value         1.0
# QB Team     2023 JAC
# RB Value        1.25
# RB Team     2021 GBP
# WR Value      3.0625
# WR Team     2023 JAC
# TE Value    1.635417
# TE Team     2022 WAS
# DT Value      2.5625
# DT Team     2022 PIT
# DE Value    2.291667
# DE Team     2022 PHI
# LB Value     2.03125
# LB Team     2023 NYG
# CB Value      2.9375
# CB Team     2023 CLE
# S Value        2.125
# S Team      2022 MIA
# DL Value     4.90625
# DL Team     2023 SEA
# DB Value      5.0625
# DB Team     2022 PIT
# Name: 47, dtype: object

# %%
# Team 49 (half of median)
result.iloc[48]
# Out:
# QB Value         1.0
# QB Team     2022 SEA
# RB Value        1.25
# RB Team     2021 MIA
# WR Value      3.0625
# WR Team     2023 PIT
# TE Value       1.625
# TE Team     2023 SEA
# DT Value      2.5625
# DT Team     2021 TBB
# DE Value    2.291667
# DE Team     2021 NYG
# LB Value         2.0
# LB Team     2023 ATL
# CB Value     2.90625
# CB Team     2022 KCC
# S Value        2.125
# S Team      2021 CLE
# DL Value       4.875
# DL Team     2022 NYG
# DB Value      5.0625
# DB Team     2023 LAC
# Name: 48, dtype: object

# %%
# Team 95
result.iloc[94]
# Out:
# QB Value         1.0
# QB Team     2022 GBP
# RB Value         1.0
# RB Team     2023 LAC
# WR Value     2.40625
# WR Team     2022 BAL
# TE Value      1.0625
# TE Team     2023 BAL
# DT Value      1.4375
# DT Team     2023 DAL
# DE Value     1.59375
# DE Team     2022 DET
# LB Value     1.59375
# LB Team     2023 MIN
# CB Value      2.1875
# CB Team     2022 BAL
# S Value       1.4375
# S Team      2021 BAL
# DL Value      4.0625
# DL Team     2023 DAL
# DB Value      4.4375
# DB Team     2022 JAC
# Name: 94, dtype: object

# %%
# Examine instances where player names don't match
print(len(df[ (df['player_pfr'] != df['player_mfl']) & (df['offense_weight'] + df['defense_weight'] > 0) ]))
# Out:
# 97

# %%
df[ (df['player_pfr'] != df['player_mfl']) & (df['offense_weight'] + df['defense_weight'] > 0) ].head(60)
# Out:
#        season team position  week          game_id  \
# 10917    2021  MIA       DE     1   2021_01_MIA_NE
# 10948    2021  MIA       DE     7  2021_07_ATL_MIA
# 17791    2021  WAS       DT     2  2021_02_NYG_WAS
# 17801    2021  WAS       DT     4  2021_04_WAS_ATL
# 17806    2021  WAS       DT     5   2021_05_NO_WAS
# 17816    2021  WAS       DT     7   2021_07_WAS_GB
# 17821    2021  WAS       DT     8  2021_08_WAS_DEN
# 17826    2021  WAS       DT    10   2021_10_TB_WAS
# 17832    2021  WAS       DT    11  2021_11_WAS_CAR
# 17844    2021  WAS       DT    13   2021_13_WAS_LV
# 17849    2021  WAS       DT    14  2021_14_DAL_WAS
# 17855    2021  WAS       DT    15  2021_15_WAS_PHI
# 17859    2021  WAS       DT    16  2021_16_WAS_DAL
# 17863    2021  WAS       DT    17  2021_17_PHI_WAS
# 17869    2021  WAS       LB     1  2021_01_LAC_WAS
# 17875    2021  WAS       LB     2  2021_02_NYG_WAS
# 17887    2021  WAS       LB     4  2021_04_WAS_ATL
# 18826    2022  ATL       CB     5   2022_05_ATL_TB
# 20592    2022  CAR       DT     1  2022_01_CLE_CAR
# 20598    2022  CAR       DT     2  2022_02_CAR_NYG
# 20603    2022  CAR       DT     3   2022_03_NO_CAR
# 20608    2022  CAR       DT     4  2022_04_ARI_CAR
# 20613    2022  CAR       DT     5   2022_05_SF_CAR
# 20618    2022  CAR       DT     6   2022_06_CAR_LA
# 20627    2022  CAR       DT     8  2022_08_CAR_ATL
# 20632    2022  CAR       DT     9  2022_09_CAR_CIN
# 20637    2022  CAR       DT    10  2022_10_ATL_CAR
# 20650    2022  CAR       DT    14  2022_14_CAR_SEA
# 20655    2022  CAR       DT    15  2022_15_PIT_CAR
# 20660    2022  CAR       DT    16  2022_16_DET_CAR
# 20665    2022  CAR       DT    17   2022_17_CAR_TB
# 27875    2022  LAR       CB    14    2022_14_LV_LA
# 27880    2022  LAR       CB    15    2022_15_LA_GB
# 27887    2022  LAR       CB    16   2022_16_DEN_LA
# 27894    2022  LAR       CB    17   2022_17_LA_LAC
# 30622    2022  NEP       WR    16   2022_16_CIN_NE
# 36002    2022  WAS       LB     9  2022_09_MIN_WAS
# 36006    2022  WAS       LB    10  2022_10_WAS_PHI
# 36011    2022  WAS       LB    11  2022_11_WAS_HOU
# 36016    2022  WAS       LB    12  2022_12_ATL_WAS
# 36021    2022  WAS       LB    13  2022_13_WAS_NYG
# 36026    2022  WAS       LB    15  2022_15_NYG_WAS
# 36898    2023  ATL       CB     1  2023_01_CAR_ATL
# 36902    2023  ATL       CB     2   2023_02_GB_ATL
# 36906    2023  ATL       CB     3  2023_03_ATL_DET
# 36911    2023  ATL       CB     4  2023_04_ATL_JAX
# 36917    2023  ATL       CB     5  2023_05_HOU_ATL
# 36922    2023  ATL       CB     6  2023_06_WAS_ATL
# 36927    2023  ATL       CB     7   2023_07_ATL_TB
# 36932    2023  ATL       CB     8  2023_08_ATL_TEN
# 36938    2023  ATL       CB     9  2023_09_MIN_ATL
# 36948    2023  ATL       CB    12   2023_12_NO_ATL
# 36954    2023  ATL       CB    13  2023_13_ATL_NYJ
# 36959    2023  ATL       CB    14   2023_14_TB_ATL
# 37144    2023  ATL       LB     2   2023_02_GB_ATL
# 37152    2023  ATL       LB     4  2023_04_ATL_JAX
# 37155    2023  ATL       LB     5  2023_05_HOU_ATL
# 37158    2023  ATL       LB     6  2023_06_WAS_ATL
# 37161    2023  ATL       LB     7   2023_07_ATL_TB
# 37165    2023  ATL       LB     8  2023_08_ATL_TEN
#
#                       join_string pfr_player_id         player_pfr  \
# 10917         Sam Eguavoen MIA DE      EguaSa00    Samuel Eguavoen
# 10948         Sam Eguavoen MIA DE      EguaSa00    Samuel Eguavoen
# 17791       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17801       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17806       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17816       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17821       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17826       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17832       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17844       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17849       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17855       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17859       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17863       Matt Ioannidis WAS DT      IoanMa01  Matthew Ioannidis
# 17869           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 17875           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 17887           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 18826           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 20592       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20598       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20603       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20608       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20613       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20618       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20627       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20632       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20637       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20650       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20655       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20660       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 20665       Matt Ioannidis CAR DT      IoanMa01  Matthew Ioannidis
# 27875       Decobie Durant LAR CB      DuraDe01       Cobie Durant
# 27880       Decobie Durant LAR CB      DuraDe01       Cobie Durant
# 27887       Decobie Durant LAR CB      DuraDe01       Cobie Durant
# 27894       Decobie Durant LAR CB      DuraDe01       Cobie Durant
# 30622  Montrell Washington DEN WR      WashSc00  Scotty Washington
# 36002           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 36006           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 36011           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 36016           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 36021           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 36026           Jon Bostic WAS LB      BostJo00    Jonathan Bostic
# 36898           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36902           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36906           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36911           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36917           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36922           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36927           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36932           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36938           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36948           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36954           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 36959           Dee Alford ATL CB      AlfoDe00    DeAundre Alford
# 37144         Nate Landman ATL LB      LandNa01     Nathan Landman
# 37152         Nate Landman ATL LB      LandNa01     Nathan Landman
# 37155         Nate Landman ATL LB      LandNa01     Nathan Landman
# 37158         Nate Landman ATL LB      LandNa01     Nathan Landman
# 37161         Nate Landman ATL LB      LandNa01     Nathan Landman
# 37165         Nate Landman ATL LB      LandNa01     Nathan Landman
#
#       pfr_position side  offense_snaps  defense_snaps           player_mfl  \
# 10917           LB  DEF            0.0           36.0         Sam Eguavoen
# 10948           LB  DEF            0.0           53.0         Sam Eguavoen
# 17791           DT  DEF            0.0           43.0       Matt Ioannidis
# 17801           DT  DEF            0.0           44.0       Matt Ioannidis
# 17806           DT  DEF            0.0           40.0       Matt Ioannidis
# 17816           DT  DEF            0.0           27.0       Matt Ioannidis
# 17821           DT  DEF            0.0           29.0       Matt Ioannidis
# 17826           DT  DEF            0.0           25.0       Matt Ioannidis
# 17832           DT  DEF            0.0           24.0       Matt Ioannidis
# 17844           DT  DEF            0.0           33.0       Matt Ioannidis
# 17849           DT  DEF            0.0           62.0       Matt Ioannidis
# 17855           DT  DEF            0.0           48.0       Matt Ioannidis
# 17859           DT  DEF            0.0           52.0       Matt Ioannidis
# 17863           DT  DEF            0.0           35.0       Matt Ioannidis
# 17869           LB  DEF            0.0           68.0           Jon Bostic
# 17875           LB  DEF            0.0           39.0           Jon Bostic
# 17887           LB  DEF            0.0           33.0           Jon Bostic
# 18826            S  DEF            0.0           53.0           Dee Alford
# 20592           DT  DEF            0.0           48.0       Matt Ioannidis
# 20598           DT  DEF            0.0           54.0       Matt Ioannidis
# 20603           DT  DEF            0.0           51.0       Matt Ioannidis
# 20608           DT  DEF            0.0           60.0       Matt Ioannidis
# 20613           DT  DEF            0.0           49.0       Matt Ioannidis
# 20618           DT  DEF            0.0           53.0       Matt Ioannidis
# 20627           DT  DEF            0.0           55.0       Matt Ioannidis
# 20632           DT  DEF            0.0           55.0       Matt Ioannidis
# 20637           DT  DEF            0.0           49.0       Matt Ioannidis
# 20650           DT  DEF            0.0           23.0       Matt Ioannidis
# 20655           DT  DEF            0.0           50.0       Matt Ioannidis
# 20660           DT  DEF            0.0           40.0       Matt Ioannidis
# 20665           DT  DEF            0.0           54.0       Matt Ioannidis
# 27875           CB  DEF            0.0           37.0       Decobie Durant
# 27880           CB  DEF            0.0           46.0       Decobie Durant
# 27887           CB  DEF            0.0           51.0       Decobie Durant
# 27894           CB  DEF            0.0           48.0       Decobie Durant
# 30622           TE  OFF           22.0            0.0  Montrell Washington
# 36002           LB  DEF            0.0           43.0           Jon Bostic
# 36006           LB  DEF            0.0           43.0           Jon Bostic
# 36011           LB  DEF            0.0           42.0           Jon Bostic
# 36016           LB  DEF            0.0           27.0           Jon Bostic
# 36021           LB  DEF            0.0           39.0           Jon Bostic
# 36026           LB  DEF            0.0           45.0           Jon Bostic
# 36898           CB  DEF            0.0           72.0           Dee Alford
# 36902           CB  DEF            0.0           24.0           Dee Alford
# 36906           CB  DEF            0.0           64.0           Dee Alford
# 36911           CB  DEF            0.0           40.0           Dee Alford
# 36917           CB  DEF            0.0           36.0           Dee Alford
# 36922           CB  DEF            0.0           46.0           Dee Alford
# 36927           CB  DEF            0.0           55.0           Dee Alford
# 36932           CB  DEF            0.0           39.0           Dee Alford
# 36938           CB  DEF            0.0           39.0           Dee Alford
# 36948           CB  DEF            0.0           46.0           Dee Alford
# 36954           CB  DEF            0.0           48.0           Dee Alford
# 36959           CB  DEF            0.0           51.0           Dee Alford
# 37144           LB  DEF            0.0           49.0         Nate Landman
# 37152           LB  DEF            0.0           54.0         Nate Landman
# 37155           LB  DEF            0.0           58.0         Nate Landman
# 37158           LB  DEF            0.0           39.0         Nate Landman
# 37161           LB  DEF            0.0           56.0         Nate Landman
# 37165           LB  DEF            0.0           56.0         Nate Landman
#
#        offense_rank  offense_thresh  offense_weight  defense_rank  \
# 10917          35.0            21.0             0.0          12.0
# 10948          33.0            30.0             0.0           4.0
# 17791          31.0            31.0             0.0          11.0
# 17801          31.0            27.0             0.0          11.0
# 17806          31.0            34.0             0.0          10.0
# 17816          32.0            30.0             0.0          12.0
# 17821          31.0            23.0             0.0          12.0
# 17826          32.0            33.0             0.0          12.0
# 17832          32.0            30.0             0.0          12.0
# 17844          32.0            34.0             0.0          10.0
# 17849          32.0            33.0             0.0           9.0
# 17855          31.0            27.0             0.0          10.0
# 17859          32.0            24.0             0.0           7.0
# 17863          30.0            22.0             0.0          11.0
# 17869          26.0            20.0             0.0           6.0
# 17875          25.0            31.0             0.0          12.0
# 17887          25.0            27.0             0.0          13.0
# 18826          21.0            21.0             0.0           8.0
# 20592          26.0            18.0             0.0          10.0
# 20598          27.0            18.0             0.0           8.0
# 20603          29.0            24.0             0.0           7.0
# 20608          30.0            22.0             0.0           7.0
# 20613          29.0            27.0             0.0           7.0
# 20618          27.0            23.0             0.0           5.0
# 20627          29.0            38.0             0.0           7.0
# 20632          29.0            18.0             0.0           7.0
# 20637          29.0            26.0             0.0           9.0
# 20650          30.0            24.0             0.0          12.0
# 20655          28.0            21.0             0.0          10.0
# 20660          28.0            30.0             0.0          11.0
# 20665          29.0            31.0             0.0          10.0
# 27875          17.0            19.0             0.0          11.0
# 27880          17.0            14.0             0.0          10.0
# 27887          20.0            38.0             0.0           6.0
# 27894          18.0            19.0             0.0           8.0
# 30622           7.0            22.0             1.0          31.0
# 36002          27.0            28.0             0.0          12.0
# 36006          28.0            40.0             0.0           8.0
# 36011          27.0            35.0             0.0           9.0
# 36016          27.0            30.0             0.0          12.0
# 36021          26.0            42.0             0.0           8.0
# 36026          26.0            36.0             0.0          10.0
# 36898          22.0            26.0             0.0           6.0
# 36902          23.0            38.0             0.0          12.0
# 36906          18.0            20.0             0.0           5.0
# 36911          21.0            19.0             0.0          10.0
# 36917          22.0            35.0             0.0          10.0
# 36922          21.0            29.0             0.0           6.0
# 36927          21.0            26.0             0.0           7.0
# 36932          22.0            31.0             0.0          11.0
# 36938          22.0            29.0             0.0          12.0
# 36948          22.0            23.0             0.0          10.0
# 36954          23.0            21.0             0.0           8.0
# 36959          22.0            23.0             0.0           7.0
# 37144          30.0            38.0             0.0           5.0
# 37152          29.0            19.0             0.0           5.0
# 37155          31.0            35.0             0.0           4.0
# 37158          31.0            29.0             0.0           9.0
# 37161          30.0            26.0             0.0           6.0
# 37165          32.0            31.0             0.0           6.0
#
#        defense_thresh  defense_weight
# 10917            36.0             1.0
# 10948            31.0             1.0
# 17791            39.0             1.0
# 17801            33.0             1.0
# 17806            22.0             1.0
# 17816            27.0             1.0
# 17821            29.0             1.0
# 17826            25.0             1.0
# 17832            24.0             1.0
# 17844            31.0             1.0
# 17849            44.0             1.0
# 17855            39.0             1.0
# 17859            38.0             1.0
# 17863            34.0             1.0
# 17869            45.0             1.0
# 17875            39.0             1.0
# 17887            33.0             0.5
# 18826            38.0             1.0
# 20592            34.0             1.0
# 20598            38.0             1.0
# 20603            37.0             1.0
# 20608            32.0             1.0
# 20613            27.0             1.0
# 20618            30.0             1.0
# 20627            20.0             1.0
# 20632            26.0             1.0
# 20637            25.0             1.0
# 20650            23.0             1.0
# 20655            28.0             1.0
# 20660            29.0             1.0
# 20665            25.0             1.0
# 27875            36.0             1.0
# 27880            34.0             1.0
# 27887            34.0             1.0
# 27894            31.0             1.0
# 30622            41.0             0.0
# 36002            43.0             1.0
# 36006            22.0             1.0
# 36011            27.0             1.0
# 36016            27.0             1.0
# 36021            35.0             1.0
# 36026            25.0             1.0
# 36898            34.0             1.0
# 36902            24.0             1.0
# 36906            19.0             1.0
# 36911            28.0             1.0
# 36917            28.0             1.0
# 36922            15.0             1.0
# 36927            32.0             1.0
# 36932            33.0             1.0
# 36938            39.0             1.0
# 36948            37.0             1.0
# 36954            36.0             1.0
# 36959            34.0             1.0
# 37144            24.0             1.0
# 37152            28.0             1.0
# 37155            28.0             1.0
# 37158            15.0             1.0
# 37161            32.0             1.0
# 37165            33.0             1.0

# %%
df[ (df['player_pfr'] != df['player_mfl']) & (df['offense_weight'] + df['defense_weight'] > 0) ].tail(60)
# Out:
#        season team position  week          game_id             join_string  \
# 36006    2022  WAS       LB    10  2022_10_WAS_PHI       Jon Bostic WAS LB
# 36011    2022  WAS       LB    11  2022_11_WAS_HOU       Jon Bostic WAS LB
# 36016    2022  WAS       LB    12  2022_12_ATL_WAS       Jon Bostic WAS LB
# 36021    2022  WAS       LB    13  2022_13_WAS_NYG       Jon Bostic WAS LB
# 36026    2022  WAS       LB    15  2022_15_NYG_WAS       Jon Bostic WAS LB
# 36898    2023  ATL       CB     1  2023_01_CAR_ATL       Dee Alford ATL CB
# 36902    2023  ATL       CB     2   2023_02_GB_ATL       Dee Alford ATL CB
# 36906    2023  ATL       CB     3  2023_03_ATL_DET       Dee Alford ATL CB
# 36911    2023  ATL       CB     4  2023_04_ATL_JAX       Dee Alford ATL CB
# 36917    2023  ATL       CB     5  2023_05_HOU_ATL       Dee Alford ATL CB
# 36922    2023  ATL       CB     6  2023_06_WAS_ATL       Dee Alford ATL CB
# 36927    2023  ATL       CB     7   2023_07_ATL_TB       Dee Alford ATL CB
# 36932    2023  ATL       CB     8  2023_08_ATL_TEN       Dee Alford ATL CB
# 36938    2023  ATL       CB     9  2023_09_MIN_ATL       Dee Alford ATL CB
# 36948    2023  ATL       CB    12   2023_12_NO_ATL       Dee Alford ATL CB
# 36954    2023  ATL       CB    13  2023_13_ATL_NYJ       Dee Alford ATL CB
# 36959    2023  ATL       CB    14   2023_14_TB_ATL       Dee Alford ATL CB
# 37144    2023  ATL       LB     2   2023_02_GB_ATL     Nate Landman ATL LB
# 37152    2023  ATL       LB     4  2023_04_ATL_JAX     Nate Landman ATL LB
# 37155    2023  ATL       LB     5  2023_05_HOU_ATL     Nate Landman ATL LB
# 37158    2023  ATL       LB     6  2023_06_WAS_ATL     Nate Landman ATL LB
# 37161    2023  ATL       LB     7   2023_07_ATL_TB     Nate Landman ATL LB
# 37165    2023  ATL       LB     8  2023_08_ATL_TEN     Nate Landman ATL LB
# 37167    2023  ATL       LB     9  2023_09_MIN_ATL     Nate Landman ATL LB
# 37171    2023  ATL       LB    10  2023_10_ATL_ARI     Nate Landman ATL LB
# 37174    2023  ATL       LB    12   2023_12_NO_ATL     Nate Landman ATL LB
# 37178    2023  ATL       LB    13  2023_13_ATL_NYJ     Nate Landman ATL LB
# 37184    2023  ATL       LB    15  2023_15_ATL_CAR     Nate Landman ATL LB
# 37187    2023  ATL       LB    16  2023_16_IND_ATL     Nate Landman ATL LB
# 37190    2023  ATL       LB    17  2023_17_ATL_CHI     Nate Landman ATL LB
# 38620    2023  CAR       CB     9  2023_09_IND_CAR  DiCaprio Bootle CAR CB
# 38625    2023  CAR       CB    10  2023_10_CAR_CHI  DiCaprio Bootle CAR CB
# 38630    2023  CAR       CB    11  2023_11_DAL_CAR  DiCaprio Bootle CAR CB
# 43646    2023  HOU       WR     1  2023_01_HOU_BAL        Tank Dell HOU WR
# 46035    2023  LAR       CB     1   2023_01_LA_SEA   Decobie Durant LAR CB
# 46039    2023  LAR       CB     2    2023_02_SF_LA   Decobie Durant LAR CB
# 46044    2023  LAR       CB     3   2023_03_LA_CIN   Decobie Durant LAR CB
# 46049    2023  LAR       CB     4   2023_04_LA_IND   Decobie Durant LAR CB
# 46054    2023  LAR       CB     5   2023_05_PHI_LA   Decobie Durant LAR CB
# 46059    2023  LAR       CB     6   2023_06_ARI_LA   Decobie Durant LAR CB
# 46064    2023  LAR       CB     7   2023_07_PIT_LA   Decobie Durant LAR CB
# 46083    2023  LAR       CB    12   2023_12_LA_ARI   Decobie Durant LAR CB
# 46094    2023  LAR       CB    14   2023_14_LA_BAL   Decobie Durant LAR CB
# 46103    2023  LAR       CB    16    2023_16_NO_LA   Decobie Durant LAR CB
# 46107    2023  LAR       CB    17   2023_17_LA_NYG   Decobie Durant LAR CB
# 51734    2023  SEA       CB     4  2023_04_SEA_NYG     Tariq Woolen SEA CB
# 51739    2023  SEA       CB     6  2023_06_SEA_CIN     Tariq Woolen SEA CB
# 51744    2023  SEA       CB     7  2023_07_ARI_SEA     Tariq Woolen SEA CB
# 51749    2023  SEA       CB     8  2023_08_CLE_SEA     Tariq Woolen SEA CB
# 51754    2023  SEA       CB     9  2023_09_SEA_BAL     Tariq Woolen SEA CB
# 51759    2023  SEA       CB    10  2023_10_WAS_SEA     Tariq Woolen SEA CB
# 51764    2023  SEA       CB    11   2023_11_SEA_LA     Tariq Woolen SEA CB
# 51770    2023  SEA       CB    12   2023_12_SF_SEA     Tariq Woolen SEA CB
# 51776    2023  SEA       CB    13  2023_13_SEA_DAL     Tariq Woolen SEA CB
# 51782    2023  SEA       CB    14   2023_14_SEA_SF     Tariq Woolen SEA CB
# 51792    2023  SEA       CB    16  2023_16_SEA_TEN     Tariq Woolen SEA CB
# 51798    2023  SEA       CB    17  2023_17_PIT_SEA     Tariq Woolen SEA CB
# 54417    2023  WAS        S    15   2023_15_WAS_LA  Jartavius Martin WAS S
# 54421    2023  WAS        S    16  2023_16_WAS_NYJ  Jartavius Martin WAS S
# 54425    2023  WAS        S    17   2023_17_SF_WAS  Jartavius Martin WAS S
#
#       pfr_player_id       player_pfr pfr_position side  offense_snaps  \
# 36006      BostJo00  Jonathan Bostic           LB  DEF            0.0
# 36011      BostJo00  Jonathan Bostic           LB  DEF            0.0
# 36016      BostJo00  Jonathan Bostic           LB  DEF            0.0
# 36021      BostJo00  Jonathan Bostic           LB  DEF            0.0
# 36026      BostJo00  Jonathan Bostic           LB  DEF            0.0
# 36898      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36902      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36906      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36911      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36917      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36922      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36927      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36932      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36938      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36948      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36954      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 36959      AlfoDe00  DeAundre Alford           CB  DEF            0.0
# 37144      LandNa01   Nathan Landman           LB  DEF            0.0
# 37152      LandNa01   Nathan Landman           LB  DEF            0.0
# 37155      LandNa01   Nathan Landman           LB  DEF            0.0
# 37158      LandNa01   Nathan Landman           LB  DEF            0.0
# 37161      LandNa01   Nathan Landman           LB  DEF            0.0
# 37165      LandNa01   Nathan Landman           LB  DEF            0.0
# 37167      LandNa01   Nathan Landman           LB  DEF            0.0
# 37171      LandNa01   Nathan Landman           LB  DEF            0.0
# 37174      LandNa01   Nathan Landman           LB  DEF            0.0
# 37178      LandNa01   Nathan Landman           LB  DEF            0.0
# 37184      LandNa01   Nathan Landman           LB  DEF            0.0
# 37187      LandNa01   Nathan Landman           LB  DEF            0.0
# 37190      LandNa01   Nathan Landman           LB  DEF            0.0
# 38620      BootDi00  Dicaprio Bootle           CB  DEF            0.0
# 38625      BootDi00  Dicaprio Bootle           CB  DEF            0.0
# 38630      BootDi00  Dicaprio Bootle           CB  DEF            0.0
# 43646      DellNa00   Nathaniel Dell           WR  OFF           37.0
# 46035      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46039      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46044      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46049      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46054      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46059      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46064      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46083      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46094      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46103      DuraDe01     Cobie Durant           CB  DEF            0.0
# 46107      DuraDe01     Cobie Durant           CB  DEF            0.0
# 51734      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51739      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51744      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51749      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51754      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51759      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51764      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51770      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51776      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51782      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51792      WoolTa00       Riq Woolen           CB  DEF            0.0
# 51798      WoolTa00       Riq Woolen           CB  DEF            0.0
# 54417      MartJa04      Quan Martin           CB  DEF            0.0
# 54421      MartJa04      Quan Martin           CB  DEF            0.0
# 54425      MartJa04      Quan Martin           CB  DEF            0.0
#
#        defense_snaps        player_mfl  offense_rank  offense_thresh  \
# 36006           43.0        Jon Bostic          28.0            40.0
# 36011           42.0        Jon Bostic          27.0            35.0
# 36016           27.0        Jon Bostic          27.0            30.0
# 36021           39.0        Jon Bostic          26.0            42.0
# 36026           45.0        Jon Bostic          26.0            36.0
# 36898           72.0        Dee Alford          22.0            26.0
# 36902           24.0        Dee Alford          23.0            38.0
# 36906           64.0        Dee Alford          18.0            20.0
# 36911           40.0        Dee Alford          21.0            19.0
# 36917           36.0        Dee Alford          22.0            35.0
# 36922           46.0        Dee Alford          21.0            29.0
# 36927           55.0        Dee Alford          21.0            26.0
# 36932           39.0        Dee Alford          22.0            31.0
# 36938           39.0        Dee Alford          22.0            29.0
# 36948           46.0        Dee Alford          22.0            23.0
# 36954           48.0        Dee Alford          23.0            21.0
# 36959           51.0        Dee Alford          22.0            23.0
# 37144           49.0      Nate Landman          30.0            38.0
# 37152           54.0      Nate Landman          29.0            19.0
# 37155           58.0      Nate Landman          31.0            35.0
# 37158           39.0      Nate Landman          31.0            29.0
# 37161           56.0      Nate Landman          30.0            26.0
# 37165           56.0      Nate Landman          32.0            31.0
# 37167           74.0      Nate Landman          31.0            29.0
# 37171           65.0      Nate Landman          31.0            28.0
# 37174           53.0      Nate Landman          30.0            23.0
# 37178           40.0      Nate Landman          31.0            21.0
# 37184           59.0      Nate Landman          30.0            20.0
# 37187           71.0      Nate Landman          32.0            24.0
# 37190           60.0      Nate Landman          32.0            17.0
# 38620           42.0   DiCaprio Bootle          22.0            31.0
# 38625           72.0   DiCaprio Bootle          20.0            27.0
# 38630           69.0   DiCaprio Bootle          23.0            27.0
# 43646            0.0         Tank Dell           6.0            35.0
# 46035           40.0    Decobie Durant          17.0            28.0
# 46039           33.0    Decobie Durant          17.0            20.0
# 46044           61.0    Decobie Durant          16.0            12.0
# 46049           45.0    Decobie Durant          18.0            23.0
# 46054           53.0    Decobie Durant          18.0             9.0
# 46059           66.0    Decobie Durant          18.0             6.0
# 46064           59.0    Decobie Durant          17.0            29.0
# 46083           32.0    Decobie Durant          20.0            24.0
# 46094           29.0    Decobie Durant          19.0            19.0
# 46103           50.0    Decobie Durant          19.0            17.0
# 46107           53.0    Decobie Durant          19.0             4.0
# 51734           73.0      Tariq Woolen          35.0            29.0
# 51739           54.0      Tariq Woolen          34.0            32.0
# 51744           66.0      Tariq Woolen          34.0            34.0
# 51749           76.0      Tariq Woolen          35.0            24.0
# 51754           65.0      Tariq Woolen          35.0            24.0
# 51759           61.0      Tariq Woolen          34.0            39.0
# 51764           67.0      Tariq Woolen          35.0            26.0
# 51770           26.0      Tariq Woolen          34.0            20.0
# 51776           87.0      Tariq Woolen          35.0            29.0
# 51782           54.0      Tariq Woolen          35.0            27.0
# 51792           66.0      Tariq Woolen          33.0            26.0
# 51798           71.0      Tariq Woolen          34.0            22.0
# 54417           75.0  Jartavius Martin          25.0            24.0
# 54421           62.0  Jartavius Martin          26.0            27.0
# 54425           63.0  Jartavius Martin          24.0            23.0
#
#        offense_weight  defense_rank  defense_thresh  defense_weight
# 36006             0.0           8.0            22.0             1.0
# 36011             0.0           9.0            27.0             1.0
# 36016             0.0          12.0            27.0             1.0
# 36021             0.0           8.0            35.0             1.0
# 36026             0.0          10.0            25.0             1.0
# 36898             0.0           6.0            34.0             1.0
# 36902             0.0          12.0            24.0             1.0
# 36906             0.0           5.0            19.0             1.0
# 36911             0.0          10.0            28.0             1.0
# 36917             0.0          10.0            28.0             1.0
# 36922             0.0           6.0            15.0             1.0
# 36927             0.0           7.0            32.0             1.0
# 36932             0.0          11.0            33.0             1.0
# 36938             0.0          12.0            39.0             1.0
# 36948             0.0          10.0            37.0             1.0
# 36954             0.0           8.0            36.0             1.0
# 36959             0.0           7.0            34.0             1.0
# 37144             0.0           5.0            24.0             1.0
# 37152             0.0           5.0            28.0             1.0
# 37155             0.0           4.0            28.0             1.0
# 37158             0.0           9.0            15.0             1.0
# 37161             0.0           6.0            32.0             1.0
# 37165             0.0           6.0            33.0             1.0
# 37167             0.0           6.0            39.0             1.0
# 37171             0.0           4.0            27.0             1.0
# 37174             0.0           6.0            37.0             1.0
# 37178             0.0          11.0            36.0             1.0
# 37184             0.0           6.0            30.0             1.0
# 37187             0.0           4.0            27.0             1.0
# 37190             0.0           5.0            33.0             1.0
# 38620             0.0           8.0            27.0             1.0
# 38625             0.0           1.0            33.0             1.0
# 38630             0.0           5.0            32.0             1.0
# 43646             1.0          34.0            29.0             0.0
# 46035             0.0           9.0            20.0             1.0
# 46039             0.0          10.0            29.0             1.0
# 46044             0.0           9.0            33.0             1.0
# 46049             0.0           9.0            33.0             1.0
# 46054             0.0          10.0            36.0             1.0
# 46059             0.0           5.0            34.0             1.0
# 46064             0.0           2.0            29.0             1.0
# 46083             0.0          11.0            31.0             1.0
# 46094             0.0          12.0            29.0             1.0
# 46103             0.0           7.0            20.0             1.0
# 46107             0.0          10.0            21.0             1.0
# 51734             0.0           3.0            38.0             1.0
# 51739             0.0           4.0            24.0             1.0
# 51744             0.0           5.0            23.0             1.0
# 51749             0.0           4.0            43.0             1.0
# 51754             0.0           5.0            38.0             1.0
# 51759             0.0           5.0            29.0             1.0
# 51764             0.0           5.0            31.0             1.0
# 51770             0.0          12.0            26.0             1.0
# 51776             0.0           4.0            36.0             1.0
# 51782             0.0           4.0            30.0             1.0
# 51792             0.0           4.0            25.0             1.0
# 51798             0.0           5.0            26.0             1.0
# 54417             0.0           3.0            35.0             1.0
# 54421             0.0           9.0            39.0             1.0
# 54425             0.0           5.0            34.0             1.0
